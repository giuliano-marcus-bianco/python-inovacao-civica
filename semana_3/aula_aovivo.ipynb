# %% [markdown]
# # Formas de baixar os csvs

# %%
from zipfile import ZipFile

import requests

# fazendo o download do conteúdo do arquivo
url = "http://www.camara.leg.br/cotas/Ano-2018.csv.zip"
r = requests.get(url)

# como acessar o conteúdo do arquivo?
# r.content

# como verificar se a requisição deu certo?
# r.status (lista de status)

file = open("Ano-2018.csv.zip", "wb")
file.write(r.content)
file.close()

zip_file = ZipFile(f"Ano-2018.csv.zip", "r")
zip_file.extract(member=f"Ano-2018.csv", path=f"reembolso-2018")
zip_file.close()

# %% [markdown]
# ## Podemos ler os arquivos de outro jeito

# %% [markdown]
# precisamos ler e escrever como `bytes objects` sem nenhum `deecoding`

# %%
with open("Ano-2018-teste.csv.zip", "w") as file:
    file.write(r.content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 with open("Ano-2018-teste.csv.zip", "w") as file:
# ----> 2     file.write(r.content)
#
# TypeError: write() argument must be str, not bytes

# %% [markdown]
# o `with` é legal porque:
#
# * ele é um gerenciador de contexto (`context manager`)
# * ele gerencia sozinho toda fase de configuração para trabalhar com um arquivo (`setup`) e o encerramento dessa seção de trabalho (`teardown`)

# %%
with open("Ano-2018-teste.csv.zip", "wb") as file:
    file.write(r.content)

# %%
with ZipFile(f"Ano-2018.csv.zip", "r") as zip_file:
    zip_file.extract(member=f"Ano-2018.csv", path=f"reembolso-2018")

# %% [markdown]
# Utilizando o pandas diretamente

# %%
import pandas as pd

pd.set_option("display.max_columns", None)

df = pd.read_csv("http://www.camara.leg.br/cotas/Ano-2018.csv.zip", sep=";", compression="zip")

df.head()
# Out:
#   txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# 0        LID.GOV-CD  NaN          NaN                    NaN           2015
# 1        LID.GOV-CD  NaN          NaN                    NaN           2015
# 2        LID.GOV-CD  NaN          NaN                    NaN           2015
# 3        LID.GOV-CD  NaN          NaN                    NaN           2015
# 4        LID.GOV-CD  NaN          NaN                    NaN           2015
#
#   sgUF sgPartido  codLegislatura  numSubCota  \
# 0  NaN       NaN              55          13
# 1  NaN       NaN              55          13
# 2  NaN       NaN              55          13
# 3  NaN       NaN              55          13
# 4  NaN       NaN              55          13
#
#                                  txtDescricao  numEspecificacaoSubCota  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 2  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 3  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 4  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
#
#   txtDescricaoEspecificacao                        txtFornecedor  \
# 0                       NaN     BISCOITOS CASEIROS HOMONNAI LTDA
# 1                       NaN  BONNA COMERCIAL DE ALIMENTOS EIRELI
# 2                       NaN            CAFE DO FLAVIO EIRELLI-ME
# 3                       NaN            CAFE DO FLAVIO EIRELLI-ME
# 4                       NaN               CRISTIANE FERREIRA EPP
#
#            txtCNPJCPF txtNumero  indTipoDocumento           datEmissao  \
# 0  046.448.200/0017-7     10473                 4  2018-12-20T00:00:00
# 1  106.385.970/0015-8       105                 4  2018-02-21T00:00:00
# 2  248.825.670/0010-5     40792                 4  2018-09-05T00:00:00
# 3  248.825.670/0010-5     42181                 4  2018-10-16T00:00:00
# 4  037.139.030/0010-8       409                 4  2018-02-05T00:00:00
#
#    vlrDocumento  vlrGlosa  vlrLiquido  numMes  numAno  numParcela  \
# 0        454.41       0.0      454.41      12    2018           0
# 1        242.90       0.0      242.90       2    2018           0
# 2         79.00       0.0       79.00       9    2018           0
# 3        207.00       0.0      207.00      10    2018           0
# 4         98.75       0.0       98.75       2    2018           0
#
#   txtPassageiro txtTrecho  numLote  numRessarcimento datPagamentoRestituicao  \
# 0           NaN       NaN  1550817               NaN                     NaN
# 1           NaN       NaN  1467117               NaN                     NaN
# 2           NaN       NaN  1527969               NaN                     NaN
# 3           NaN       NaN  1532624               NaN                     NaN
# 4           NaN       NaN  1460984               NaN                     NaN
#
#    vlrRestituicao  nuDeputadoId  ideDocumento  \
# 0             NaN          2812       6728796
# 1             NaN          2812       6508293
# 2             NaN          2812       6666881
# 3             NaN          2812       6681167
# 4             NaN          2812       6491959
#
#                                         urlDocumento
# 0  https://www.camara.leg.br/cota-parlamentar/not...
# 1  https://www.camara.leg.br/cota-parlamentar/not...
# 2  https://www.camara.leg.br/cota-parlamentar/not...
# 3  https://www.camara.leg.br/cota-parlamentar/not...
# 4  https://www.camara.leg.br/cota-parlamentar/not...

# %% [markdown]
# # Qual a importância de passar o tipo das colunas na hora de leitura do csv?
#
# O pandas pode errar quando tenta determinar o tipo das variáveis (ele lê todos os dados antes), para facilitar isso, passamos o tipo das colunas.

# %%
df.dtypes
# Out:
# txNomeParlamentar             object
# cpf                          float64
# ideCadastro                  float64
# nuCarteiraParlamentar        float64
# nuLegislatura                  int64
# sgUF                          object
# sgPartido                     object
# codLegislatura                 int64
# numSubCota                     int64
# txtDescricao                  object
# numEspecificacaoSubCota        int64
# txtDescricaoEspecificacao     object
# txtFornecedor                 object
# txtCNPJCPF                    object
# txtNumero                     object
# indTipoDocumento               int64
# datEmissao                    object
# vlrDocumento                 float64
# vlrGlosa                     float64
# vlrLiquido                   float64
# numMes                         int64
# numAno                         int64
# numParcela                     int64
# txtPassageiro                 object
# txtTrecho                     object
# numLote                        int64
# numRessarcimento             float64
# datPagamentoRestituicao       object
# vlrRestituicao               float64
# nuDeputadoId                   int64
# ideDocumento                   int64
# urlDocumento                  object
# dtype: object

# %%
DTYPE = {
    "txNomeParlamentar": str,
    "cpf": str,
    "ideCadastro": str,
    "nuCarteiraParlamentar": str,
    "nuLegislatura": str,
    "sgUF": str,
    "sgPartido": str,
    "codLegislatura": str,
    "numSubCota": str,
    "txtDescricao": str,
    "numEspecificacaoSubCota": str,
    "txtDescricaoEspecificacao": str,
    "txtFornecedor": str,
    "txtCNPJCPF": str,
    "txtNumero": str,
    "indTipoDocumento": str,
    "datEmissao": str,
    "vlrDocumento": float,
    "vlrGlosa": str,
    "vlrLiquido": float,
    "numMes": str,
    "numAno": str,
    "numParcela": str,
    "txtPassageiro": str,
    "txtTrecho": str,
    "numLote": str,
    "numRessarcimento": str,
    "nuDeputadoId": str,
    "ideDocumento": str,
}

df_reembolso = pd.read_csv(
    "http://www.camara.leg.br/cotas/Ano-2018.csv.zip", sep=";", compression="zip", dtype=DTYPE
)

# %%
df_reembolso.dtypes
# Out:
# txNomeParlamentar             object
# cpf                           object
# ideCadastro                   object
# nuCarteiraParlamentar         object
# nuLegislatura                 object
# sgUF                          object
# sgPartido                     object
# codLegislatura                object
# numSubCota                    object
# txtDescricao                  object
# numEspecificacaoSubCota       object
# txtDescricaoEspecificacao     object
# txtFornecedor                 object
# txtCNPJCPF                    object
# txtNumero                     object
# indTipoDocumento              object
# datEmissao                    object
# vlrDocumento                 float64
# vlrGlosa                      object
# vlrLiquido                   float64
# numMes                        object
# numAno                        object
# numParcela                    object
# txtPassageiro                 object
# txtTrecho                     object
# numLote                       object
# numRessarcimento              object
# datPagamentoRestituicao       object
# vlrRestituicao               float64
# nuDeputadoId                  object
# ideDocumento                  object
# urlDocumento                  object
# dtype: object

# %% [markdown]
# # Funções úteis

# %% [markdown]
# ## `astype()`

# %%
df_reembolso.astype("object").dtypes
# Out:
# txNomeParlamentar            object
# cpf                          object
# ideCadastro                  object
# nuCarteiraParlamentar        object
# nuLegislatura                object
# sgUF                         object
# sgPartido                    object
# codLegislatura               object
# numSubCota                   object
# txtDescricao                 object
# numEspecificacaoSubCota      object
# txtDescricaoEspecificacao    object
# txtFornecedor                object
# txtCNPJCPF                   object
# txtNumero                    object
# indTipoDocumento             object
# datEmissao                   object
# vlrDocumento                 object
# vlrGlosa                     object
# vlrLiquido                   object
# numMes                       object
# numAno                       object
# numParcela                   object
# txtPassageiro                object
# txtTrecho                    object
# numLote                      object
# numRessarcimento             object
# datPagamentoRestituicao      object
# vlrRestituicao               object
# nuDeputadoId                 object
# ideDocumento                 object
# urlDocumento                 object
# dtype: object

# %%
df_reembolso.astype({"vlrRestituicao": "object"}).dtypes
# Out:
# txNomeParlamentar             object
# cpf                           object
# ideCadastro                   object
# nuCarteiraParlamentar         object
# nuLegislatura                 object
# sgUF                          object
# sgPartido                     object
# codLegislatura                object
# numSubCota                    object
# txtDescricao                  object
# numEspecificacaoSubCota       object
# txtDescricaoEspecificacao     object
# txtFornecedor                 object
# txtCNPJCPF                    object
# txtNumero                     object
# indTipoDocumento              object
# datEmissao                    object
# vlrDocumento                 float64
# vlrGlosa                      object
# vlrLiquido                   float64
# numMes                        object
# numAno                        object
# numParcela                    object
# txtPassageiro                 object
# txtTrecho                     object
# numLote                       object
# numRessarcimento              object
# datPagamentoRestituicao       object
# vlrRestituicao                object
# nuDeputadoId                  object
# ideDocumento                  object
# urlDocumento                  object
# dtype: object

# %% [markdown]
# ## `to_datetime()`

# %%
df_reembolso.datEmissao.dtypes
# Out:
# dtype('O')

# %%
df_reembolso.datEmissao
# Out:
# 0         2018-12-20T00:00:00
# 1         2018-02-21T00:00:00
# 2         2018-09-05T00:00:00
# 3         2018-10-16T00:00:00
# 4         2018-02-05T00:00:00
#                  ...
# 292785                    NaN
# 292786    2018-12-20T00:00:00
# 292787    2018-12-20T00:00:00
# 292788    2019-01-08T00:00:00
# 292789    2018-12-28T00:00:00
# Name: datEmissao, Length: 292790, dtype: object

# %%
pd.to_datetime(df_reembolso.datEmissao, format="%Y-%m-%dT%H:%M:%S")
# Out:
# 0        2018-12-20
# 1        2018-02-21
# 2        2018-09-05
# 3        2018-10-16
# 4        2018-02-05
#             ...
# 292785          NaT
# 292786   2018-12-20
# 292787   2018-12-20
# 292788   2019-01-08
# 292789   2018-12-28
# Name: datEmissao, Length: 292790, dtype: datetime64[ns]

# %%
df_reembolso_2 = pd.read_csv(
    "http://www.camara.leg.br/cotas/Ano-2019.csv.zip",
    sep=";",
    compression="zip",
    dtype=DTYPE,
    parse_dates=["datEmissao"],
)

# %%
df_reembolso_2.datEmissao
# Out:
# 0        2019-01-16
# 1        2019-02-04
# 2        2019-02-25
# 3        2019-03-28
# 4        2019-05-07
#             ...
# 289448   2019-12-11
# 289449   2019-12-31
# 289450   2019-12-18
# 289451          NaT
# 289452   2020-01-31
# Name: datEmissao, Length: 289453, dtype: datetime64[ns]

# %% [markdown]
# ### Coisinhas legais com datas

# %%
df_reembolso_2.datEmissao.dt

# %%
df_reembolso_2.datEmissao.dt.day_name()
# Out:
# 0         Wednesday
# 1            Monday
# 2            Monday
# 3          Thursday
# 4           Tuesday
#             ...
# 289448    Wednesday
# 289449      Tuesday
# 289450    Wednesday
# 289451          NaN
# 289452       Friday
# Name: datEmissao, Length: 289453, dtype: object

# %%
df_reembolso_2.datEmissao.dt.dayofweek
# Out:
# 0         2.0
# 1         0.0
# 2         0.0
# 3         3.0
# 4         1.0
#          ...
# 289448    2.0
# 289449    1.0
# 289450    2.0
# 289451    NaN
# 289452    4.0
# Name: datEmissao, Length: 289453, dtype: float64

# %%
df_reembolso_2.datEmissao.dt.year
# Out:
# 0         2019.0
# 1         2019.0
# 2         2019.0
# 3         2019.0
# 4         2019.0
#            ...
# 289448    2019.0
# 289449    2019.0
# 289450    2019.0
# 289451       NaN
# 289452    2020.0
# Name: datEmissao, Length: 289453, dtype: float64

# %%
df_reembolso_2.datEmissao.dt.month
# Out:
# 0          1.0
# 1          2.0
# 2          2.0
# 3          3.0
# 4          5.0
#           ...
# 289448    12.0
# 289449    12.0
# 289450    12.0
# 289451     NaN
# 289452     1.0
# Name: datEmissao, Length: 289453, dtype: float64

# %% [markdown]
# ### Intervalo de datas (range de datas)

# %% [markdown]
# Definição (em inglês):
#
# > `.loc` access a group of rows and columns by label(s) or a boolean array.
#
# > `.loc[]` is primarily label based, but may also be used with a boolean array.

# %%
df_reembolso_2.loc[
    (df_reembolso_2.datEmissao >= "2018-01-01") & (df_reembolso_2.datEmissao <= "2019-07-30")
].sort_values(by='datEmissao')
# Out:
#              txNomeParlamentar          cpf ideCadastro nuCarteiraParlamentar  \
# 106023             Pedro Uczai  47721855934      160604                   481
# 173133        MARCELO DELAROLI  08829637750      195826                   592
# 13268       Hermes Parcianello  33496315920       73772                   448
# 141161      Joaquim Passarinho  13606328249      178910                    33
# 138917  DELEGADO EDSON MOREIRA  22063625115      178893                   229
# ...                        ...          ...         ...                   ...
# 288111             Bia Cavassa  49200844120      207176                   532
# 288112             Bia Cavassa  49200844120      207176                   532
# 288113             Bia Cavassa  49200844120      207176                   532
# 50610          Gleisi Hoffmann  67677061915      107283                   451
# 261089            Rosana Valle  10851776884      204525                   388
#
#        nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 106023          2019   SC        PT             56          1
# 173133          2015   RJ        PR             55          9
# 13268           2019   PR       MDB             56          9
# 141161          2015   PA       PSD             55          1
# 138917          2015   MG        PR             55        122
# ...              ...  ...       ...            ...        ...
# 288111          2019   MS      PSDB             56        999
# 288112          2019   MS      PSDB             56        999
# 288113          2019   MS      PSDB             56        999
# 50610           2019   PR        PT             56          3
# 261089          2019   SP        PL             56          1
#
#                                              txtDescricao  \
# 106023  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 173133                         PASSAGEM AÉREA - REEMBOLSO
# 13268                          PASSAGEM AÉREA - REEMBOLSO
# 141161  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 138917          SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO
# ...                                                   ...
# 288111                               PASSAGEM AÉREA - RPA
# 288112                               PASSAGEM AÉREA - RPA
# 288113                               PASSAGEM AÉREA - RPA
# 50610                       COMBUSTÍVEIS E LUBRIFICANTES.
# 261089  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
#
#        numEspecificacaoSubCota txtDescricaoEspecificacao  \
# 106023                       0                       NaN
# 173133                       0                       NaN
# 13268                        0                       NaN
# 141161                       0                       NaN
# 138917                       0                       NaN
# ...                        ...                       ...
# 288111                       0                       NaN
# 288112                       0                       NaN
# 288113                       0                       NaN
# 50610                        1      Veículos Automotores
# 261089                       0                       NaN
#
#                                       txtFornecedor          txtCNPJCPF  \
# 106023                     IMOBILIARIA MARKIZE LTDA  831.627.680/0019-9
# 173133                       TAM LINHAS AEREAS S/A.  020.128.620/0016-0
# 13268                GOL LINHAS AÉREAS INTELIGENTES  075.756.510/0015-9
# 141161                  IDEIAS CONCRETAS ASSESSORIA  036.437.830/0011-0
# 138917                        Autopista Fernão Dias  093.263.420/0017-0
# ...                                             ...                 ...
# 288111                              Cia Aérea - TAM  020.128.620/0016-0
# 288112                              Cia Aérea - TAM  020.128.620/0016-0
# 288113                              Cia Aérea - TAM  020.128.620/0016-0
# 50610            POSTO DE COMBUSTIVEIS 214 SUL LTDA  083.558.250/0013-0
# 261089  ALEXANDRE MORGADO ME / MORGATEC INFORMATICA  048.710.810/0015-6
#
#                        txtNumero indTipoDocumento datEmissao  vlrDocumento  \
# 106023                     33370                0 2018-06-13       3420.40
# 173133             9572165461065                0 2018-11-06       1079.00
# 13268             12700384862611                0 2018-11-12       1347.18
# 141161                        sn                1 2018-11-20       3923.15
# 138917                    001430                1 2018-11-22          2.30
# ...                          ...              ...        ...           ...
# 288111  Bilhete: 957-2106.121668                0 2019-07-30        466.79
# 288112  Bilhete: 957-2106.122666                0 2019-07-30        845.79
# 288113  Bilhete: 957-2106.123545                0 2019-07-30        849.39
# 50610                       9642                4 2019-07-30        195.10
# 261089                      2373                0 2019-07-30       1385.00
#
#        vlrGlosa  vlrLiquido numMes numAno numParcela  \
# 106023        0     3420.40      3   2019          0
# 173133        0     1079.00      1   2019          0
# 13268         0     1347.18      2   2019          0
# 141161        0     3923.15      1   2019          0
# 138917        0        2.30      1   2019          0
# ...         ...         ...    ...    ...        ...
# 288111        0      466.79      7   2019          0
# 288112        0      845.79      7   2019          0
# 288113        0      849.39      7   2019          0
# 50610         0      195.10      7   2019          0
# 261089        0     1385.00      7   2019          0
#
#                                           txtPassageiro txtTrecho  numLote  \
# 106023                                              NaN       NaN  1580956
# 173133  MARCELO DE SOUZA LEITE; MARCELO DE SOUZA LEITE;       NaN  1553756
# 13268                                               NaN       NaN  1579328
# 141161                                              NaN       NaN  1558134
# 138917                                              NaN       NaN  1555153
# ...                                                 ...       ...      ...
# 288111                                      Bia Cavassa   BSB/CGR        0
# 288112                                      Bia Cavassa   CGR/BSB        0
# 288113                                      Bia Cavassa   BSB/CGR        0
# 50610                                               NaN       NaN  1616431
# 261089                                              NaN       NaN  1622239
#
#        numRessarcimento datPagamentoRestituicao  vlrRestituicao nuDeputadoId  \
# 106023              NaN                     NaN             NaN         2243
# 173133              NaN                     NaN             NaN         3166
# 13268               NaN                     NaN             NaN         1042
# 141161              NaN                     NaN             NaN         2973
# 138917              NaN                     NaN             NaN         2920
# ...                 ...                     ...             ...          ...
# 288111                0                     NaN             NaN         3445
# 288112                0                     NaN             NaN         3445
# 288113                0                     NaN             NaN         3445
# 50610               NaN                     NaN             NaN         3430
# 261089              NaN                     NaN             NaN         3281
#
#        ideDocumento                                       urlDocumento
# 106023      6797553  https://www.camara.leg.br/cota-parlamentar/doc...
# 173133      6736884  https://www.camara.leg.br/cota-parlamentar/doc...
# 13268       6793569  https://www.camara.leg.br/cota-parlamentar/doc...
# 141161      6746924  https://www.camara.leg.br/cota-parlamentar/doc...
# 138917      6740684  https://www.camara.leg.br/cota-parlamentar/doc...
# ...             ...                                                ...
# 288111      1688380                                                NaN
# 288112      1688383                                                NaN
# 288113      1688386                                                NaN
# 50610       6880012  https://www.camara.leg.br/cota-parlamentar/not...
# 261089      6893979  https://www.camara.leg.br/cota-parlamentar/doc...
#
# [159958 rows x 32 columns]

# %%
df_reembolso_2.set_index("datEmissao").loc['2018-11-22':'2019-07-30'].sort_values(by='datEmissao')
# Out:
#                           txNomeParlamentar          cpf ideCadastro  \
# datEmissao
# 2018-11-22 00:00:00  DELEGADO EDSON MOREIRA  22063625115      178893
# 2018-12-01 00:00:00            Alex Manente  26838194805      178972
# 2018-12-01 00:00:00            Alex Manente  26838194805      178972
# 2018-12-01 00:00:00            Alex Manente  26838194805      178972
# 2018-12-03 00:00:00           Antonio Brito  51488868549      160553
# ...                                     ...          ...         ...
# 2019-07-30 16:39:09     Alexandre Serfiotis  02440200786      178833
# 2019-07-30 16:56:41              Raul Henry  45877475487      141523
# 2019-07-30 16:56:56             Odair Cunha  94892393649       74159
# 2019-07-30 16:57:18        Gonzaga Patriota  01960970453       74419
# 2019-07-30 17:11:18          Márcio Marinho  01895263786      150418
#
#                     nuCarteiraParlamentar nuLegislatura sgUF     sgPartido  \
# datEmissao
# 2018-11-22 00:00:00                   229          2015   MG            PR
# 2018-12-01 00:00:00                   331          2019   SP     CIDADANIA
# 2018-12-01 00:00:00                   331          2019   SP     CIDADANIA
# 2018-12-01 00:00:00                   331          2019   SP     CIDADANIA
# 2018-12-03 00:00:00                   189          2015   BA           PSD
# ...                                   ...           ...  ...           ...
# 2019-07-30 16:39:09                   284          2019   RJ           PSD
# 2019-07-30 16:56:41                   153          2019   PE           MDB
# 2019-07-30 16:56:56                   269          2019   MG            PT
# 2019-07-30 16:57:18                   143          2019   PE           PSB
# 2019-07-30 17:11:18                   212          2019   BA  REPUBLICANOS
#
#                     codLegislatura numSubCota  \
# datEmissao
# 2018-11-22 00:00:00             55        122
# 2018-12-01 00:00:00             56          1
# 2018-12-01 00:00:00             56          1
# 2018-12-01 00:00:00             56          1
# 2018-12-03 00:00:00             55          3
# ...                            ...        ...
# 2019-07-30 16:39:09             56         11
# 2019-07-30 16:56:41             56         11
# 2019-07-30 16:56:56             56         11
# 2019-07-30 16:57:18             56         11
# 2019-07-30 17:11:18             56         11
#
#                                                           txtDescricao  \
# datEmissao
# 2018-11-22 00:00:00          SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO
# 2018-12-01 00:00:00  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2018-12-01 00:00:00  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2018-12-01 00:00:00  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2018-12-03 00:00:00                      COMBUSTÍVEIS E LUBRIFICANTES.
# ...                                                                ...
# 2019-07-30 16:39:09                                   SERVIÇOS POSTAIS
# 2019-07-30 16:56:41                                   SERVIÇOS POSTAIS
# 2019-07-30 16:56:56                                   SERVIÇOS POSTAIS
# 2019-07-30 16:57:18                                   SERVIÇOS POSTAIS
# 2019-07-30 17:11:18                                   SERVIÇOS POSTAIS
#
#                     numEspecificacaoSubCota txtDescricaoEspecificacao  \
# datEmissao
# 2018-11-22 00:00:00                       0                       NaN
# 2018-12-01 00:00:00                       0                       NaN
# 2018-12-01 00:00:00                       0                       NaN
# 2018-12-01 00:00:00                       0                       NaN
# 2018-12-03 00:00:00                       1      Veículos Automotores
# ...                                     ...                       ...
# 2019-07-30 16:39:09                       0                       NaN
# 2019-07-30 16:56:41                       0                       NaN
# 2019-07-30 16:56:56                       0                       NaN
# 2019-07-30 16:57:18                       0                       NaN
# 2019-07-30 17:11:18                       0                       NaN
#
#                                           txtFornecedor          txtCNPJCPF  \
# datEmissao
# 2018-11-22 00:00:00               Autopista Fernão Dias  093.263.420/0017-0
# 2018-12-01 00:00:00  MUNICIPIO DE SAO BERNARDO DO CAMPO  465.232.390/0014-7
# 2018-12-01 00:00:00  MUNICIPIO DE SAO BERNARDO DO CAMPO  465.232.390/0014-7
# 2018-12-01 00:00:00  MUNICIPIO DE SAO BERNARDO DO CAMPO  465.232.390/0014-7
# 2018-12-03 00:00:00       AUTO POSTO BORDA DA MATA LTDA  063.192.200/0016-9
# ...                                                 ...                 ...
# 2019-07-30 16:39:09          CORREIOS - SEDEX 12 COM AR  000.000.000/0000-7
# 2019-07-30 16:56:41            CORREIOS - ENCOMENDA PAC  000.000.000/0000-7
# 2019-07-30 16:56:56            CORREIOS - ENCOMENDA PAC  000.000.000/0000-7
# 2019-07-30 16:57:18       CORREIOS - SEDEX CONVENCIONAL  000.000.000/0000-7
# 2019-07-30 17:11:18                 CORREIOS - SEDEX 10  000.000.000/0000-7
#
#                              txtNumero indTipoDocumento  vlrDocumento  \
# datEmissao
# 2018-11-22 00:00:00             001430                1          2.30
# 2018-12-01 00:00:00  30627613190888265                1        159.65
# 2018-12-01 00:00:00  30627613190888295                1        159.65
# 2018-12-01 00:00:00  30627613190888280                1        159.65
# 2018-12-03 00:00:00              78829                4         50.03
# ...                                ...              ...           ...
# 2019-07-30 16:39:09      RSP : 2284353                1        134.06
# 2019-07-30 16:56:41      RSP : 2284368                1         42.41
# 2019-07-30 16:56:56      RSP : 2284309                1        136.56
# 2019-07-30 16:57:18      RSP : 2284374                1         70.97
# 2019-07-30 17:11:18      RSP : 2284376                1         95.00
#
#                     vlrGlosa  vlrLiquido numMes numAno numParcela  \
# datEmissao
# 2018-11-22 00:00:00        0        2.30      1   2019          0
# 2018-12-01 00:00:00        0      159.65      2   2019          0
# 2018-12-01 00:00:00        0      159.65      2   2019          0
# 2018-12-01 00:00:00        0      159.65      2   2019          0
# 2018-12-03 00:00:00        0       50.03      1   2019          0
# ...                      ...         ...    ...    ...        ...
# 2019-07-30 16:39:09        0      134.06      7   2019          0
# 2019-07-30 16:56:41        0       42.41      7   2019          0
# 2019-07-30 16:56:56        0      136.56      7   2019          0
# 2019-07-30 16:57:18        0       70.97      7   2019          0
# 2019-07-30 17:11:18        0       95.00      7   2019          0
#
#                     txtPassageiro txtTrecho  numLote numRessarcimento  \
# datEmissao
# 2018-11-22 00:00:00           NaN       NaN  1555153              NaN
# 2018-12-01 00:00:00           NaN       NaN  1570003              NaN
# 2018-12-01 00:00:00           NaN       NaN  1570003              NaN
# 2018-12-01 00:00:00           NaN       NaN  1570003              NaN
# 2018-12-03 00:00:00           NaN       NaN  1557838              NaN
# ...                           ...       ...      ...              ...
# 2019-07-30 16:39:09           NaN       NaN        0                0
# 2019-07-30 16:56:41           NaN       NaN        0                0
# 2019-07-30 16:56:56           NaN       NaN        0                0
# 2019-07-30 16:57:18           NaN       NaN        0                0
# 2019-07-30 17:11:18           NaN       NaN        0                0
#
#                     datPagamentoRestituicao  vlrRestituicao nuDeputadoId  \
# datEmissao
# 2018-11-22 00:00:00                     NaN             NaN         2920
# 2018-12-01 00:00:00                     NaN             NaN         3011
# 2018-12-01 00:00:00                     NaN             NaN         3011
# 2018-12-01 00:00:00                     NaN             NaN         3011
# 2018-12-03 00:00:00                     NaN             NaN         2407
# ...                                     ...             ...          ...
# 2019-07-30 16:39:09                     NaN             NaN         3070
# 2019-07-30 16:56:41                     NaN             NaN         1918
# 2019-07-30 16:56:56                     NaN             NaN         1625
# 2019-07-30 16:57:18                     NaN             NaN          137
# 2019-07-30 17:11:18                     NaN             NaN         1987
#
#                     ideDocumento  \
# datEmissao
# 2018-11-22 00:00:00      6740684
# 2018-12-01 00:00:00      6769381
# 2018-12-01 00:00:00      6769378
# 2018-12-01 00:00:00      6769377
# 2018-12-03 00:00:00      6745841
# ...                          ...
# 2019-07-30 16:39:09            0
# 2019-07-30 16:56:41            0
# 2019-07-30 16:56:56            0
# 2019-07-30 16:57:18            0
# 2019-07-30 17:11:18            0
#
#                                                           urlDocumento
# datEmissao
# 2018-11-22 00:00:00  https://www.camara.leg.br/cota-parlamentar/doc...
# 2018-12-01 00:00:00  https://www.camara.leg.br/cota-parlamentar/doc...
# 2018-12-01 00:00:00  https://www.camara.leg.br/cota-parlamentar/doc...
# 2018-12-01 00:00:00  https://www.camara.leg.br/cota-parlamentar/doc...
# 2018-12-03 00:00:00  https://www.camara.leg.br/cota-parlamentar/not...
# ...                                                                ...
# 2019-07-30 16:39:09                                                NaN
# 2019-07-30 16:56:41                                                NaN
# 2019-07-30 16:56:56                                                NaN
# 2019-07-30 16:57:18                                                NaN
# 2019-07-30 17:11:18                                                NaN
#
# [160001 rows x 31 columns]

# %% [markdown]
# # O caso do `vlrLiquido`
#
# Aqui nós podemos ver que temos valores negativos. Esse valores são referentes a bilhetes de compensação, bilhete de compensação é o bilhete aéreo não voado, que foi reembolsado à Câmara dos Deputados. Portanto, o valor relativo aos bilhetes compensados (não voados) são reembolsados/devolvidos à Casa, deduzindo-se as taxas de cancelamento e de no-show, de acordo com as regras tarifárias da companhia aérea respectiva.
#
# Esse crédito pode voltar para a conta corrente do parlamentar mantida na companhia aérea para ser utilizado com nova emissão de passagem aérea ou poderá voltar para a CEAP do respectivo parlamentar, ficando disponível para utilização com as demais despesas.

# %%
df_reembolso.vlrLiquido.min()
# Out:
# -4906.0

# %%
df_reembolso.vlrLiquido.describe()
# Out:
# count    292790.000000
# mean        735.774893
# std        2480.869955
# min       -4906.000000
# 25%          50.000000
# 50%         192.110000
# 75%         671.030000
# max      130000.000000
# Name: vlrLiquido, dtype: float64

# %%
negative_documents = df_reembolso_2[df_reembolso_2["vlrLiquido"] < 0]

len(negative_documents)
# Out:
# 10739

# %%
negative_documents["ideDocumento"]
# Out:
# 920       1640498
# 1759         2203
# 1763         2275
# 1766         1660
# 1772          313
#            ...
# 289164    1708904
# 289176    1723048
# 289177    1724703
# 289178    1723049
# 289318    1724810
# Name: ideDocumento, Length: 10739, dtype: object

# %%
positive_documents = df_reembolso_2[
    (df_reembolso_2["ideDocumento"].isin(negative_documents["ideDocumento"]))
    & (df_reembolso_2["vlrLiquido"] > 0)
]
positive_documents.head()
# Out:
#      txNomeParlamentar          cpf ideCadastro nuCarteiraParlamentar  \
# 1758     Fausto Pinato  28022995819       66828                   355
# 1762     Fausto Pinato  28022995819       66828                   355
# 1765     Fausto Pinato  28022995819       66828                   355
# 1771     Fausto Pinato  28022995819       66828                   355
# 3113           Bacelar  10626409500       69871                   184
#
#      nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 1758          2019   SP        PP             56        998
# 1762          2019   SP        PP             56        998
# 1765          2019   SP        PP             56        998
# 1771          2019   SP        PP             56        998
# 3113          2019   BA        PV             56        998
#
#                  txtDescricao numEspecificacaoSubCota  \
# 1758  PASSAGEM AÉREA - SIGEPA                       0
# 1762  PASSAGEM AÉREA - SIGEPA                       0
# 1765  PASSAGEM AÉREA - SIGEPA                       0
# 1771  PASSAGEM AÉREA - SIGEPA                       0
# 3113  PASSAGEM AÉREA - SIGEPA                       0
#
#      txtDescricaoEspecificacao txtFornecedor txtCNPJCPF txtNumero  \
# 1758                       NaN           GOL        NaN    GLLN8G
# 1762                       NaN           GOL        NaN    KSKZ8B
# 1765                       NaN           GOL        NaN    LM8MGG
# 1771                       NaN           GOL        NaN    VRF7MH
# 3113                       NaN           GOL        NaN    CR6F4R
#
#      indTipoDocumento          datEmissao  vlrDocumento vlrGlosa  vlrLiquido  \
# 1758                0 2019-11-20 12:00:00       1386.50        0     1386.50
# 1762                0 2019-11-21 12:00:00       1791.57        0     1791.57
# 1765                0 2019-10-21 12:00:00       1277.57        0     1277.57
# 1771                0 2019-07-17 12:00:00       1432.88        0     1432.88
# 3113                0 2019-10-10 12:00:00       1046.13        0     1046.13
#
#      numMes numAno numParcela                txtPassageiro txtTrecho numLote  \
# 1758     11   2019          0            Fausto Ruy Pinato   BSB/CGH       0
# 1762     11   2019          0            Fausto Ruy Pinato   BSB/CGH       0
# 1765     10   2019          0     Roberto Holanda Craveiro   BSB/GRU       0
# 1771      7   2019          0            Fausto Ruy Pinato   SDU/BSB       0
# 3113     10   2019          0  JOAO CARLOS BACELAR BATISTA   SSA/BSB       0
#
#      numRessarcimento datPagamentoRestituicao  vlrRestituicao nuDeputadoId  \
# 1758                0                     NaN             NaN         2917
# 1762                0                     NaN             NaN         2917
# 1765                0                     NaN             NaN         2917
# 1771                0                     NaN             NaN         2917
# 3113                0                     NaN             NaN         2985
#
#      ideDocumento urlDocumento
# 1758         2203          NaN
# 1762         2275          NaN
# 1765         1660          NaN
# 1771          313          NaN
# 3113         1503          NaN

# %%
len(positive_documents)
# Out:
# 601

# %%
positive_documents.iloc[0].to_frame()
# Out:
#                                               1758
# txNomeParlamentar                    Fausto Pinato
# cpf                                    28022995819
# ideCadastro                                  66828
# nuCarteiraParlamentar                          355
# nuLegislatura                                 2019
# sgUF                                            SP
# sgPartido                                       PP
# codLegislatura                                  56
# numSubCota                                     998
# txtDescricao               PASSAGEM AÉREA - SIGEPA
# numEspecificacaoSubCota                          0
# txtDescricaoEspecificacao                      NaN
# txtFornecedor                                  GOL
# txtCNPJCPF                                     NaN
# txtNumero                                   GLLN8G
# indTipoDocumento                                 0
# datEmissao                     2019-11-20 12:00:00
# vlrDocumento                                1386.5
# vlrGlosa                                         0
# vlrLiquido                                  1386.5
# numMes                                          11
# numAno                                        2019
# numParcela                                       0
# txtPassageiro                    Fausto Ruy Pinato
# txtTrecho                                  BSB/CGH
# numLote                                          0
# numRessarcimento                                 0
# datPagamentoRestituicao                        NaN
# vlrRestituicao                                 NaN
# nuDeputadoId                                  2917
# ideDocumento                                  2203
# urlDocumento                                   NaN

# %%
sample = negative_documents[negative_documents.duplicated(subset="ideDocumento")].iloc[
    1
]  # , keep = {‘last’, ‘first’, ‘false’)

# %%
df_reembolso_2[df_reembolso_2["ideDocumento"] == sample["ideDocumento"]]
# Out:
#      txNomeParlamentar          cpf ideCadastro nuCarteiraParlamentar  \
# 3134           Bacelar  10626409500       69871                   184
# 3135           Bacelar  10626409500       69871                   184
# 3136           Bacelar  10626409500       69871                   184
#
#      nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 3134          2019   BA        PV             56        998
# 3135          2019   BA        PV             56        998
# 3136          2019   BA        PV             56        998
#
#                  txtDescricao numEspecificacaoSubCota  \
# 3134  PASSAGEM AÉREA - SIGEPA                       0
# 3135  PASSAGEM AÉREA - SIGEPA                       0
# 3136  PASSAGEM AÉREA - SIGEPA                       0
#
#      txtDescricaoEspecificacao txtFornecedor txtCNPJCPF txtNumero  \
# 3134                       NaN           GOL        NaN    RMQ2VW
# 3135                       NaN           GOL        NaN    RMQ2VW
# 3136                       NaN           GOL        NaN    RMQ2VW
#
#      indTipoDocumento          datEmissao  vlrDocumento vlrGlosa  vlrLiquido  \
# 3134                0 2019-09-26 12:00:00       1423.46        0     1423.46
# 3135                0 2019-10-01 12:00:00        -25.00        0      -25.00
# 3136                0 2019-11-28 12:00:00      -1330.14        0    -1330.14
#
#      numMes numAno numParcela                txtPassageiro txtTrecho numLote  \
# 3134      9   2019          0  JOAO CARLOS BACELAR BATISTA   SSA/BSB       0
# 3135     10   2019          0  JOAO CARLOS BACELAR BATISTA   SSA/BSB       0
# 3136     11   2019          0  JOAO CARLOS BACELAR BATISTA   BSB/BSB       0
#
#      numRessarcimento datPagamentoRestituicao  vlrRestituicao nuDeputadoId  \
# 3134                0                     NaN             NaN         2985
# 3135                0                     NaN             NaN         2985
# 3136                0                     NaN             NaN         2985
#
#      ideDocumento urlDocumento
# 3134         1205          NaN
# 3135         1205          NaN
# 3136         1205          NaN
