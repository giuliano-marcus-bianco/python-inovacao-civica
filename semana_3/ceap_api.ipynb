# %% [markdown]
# # Escola de Dados - Python para inovação cívica
#
# ## Semana 3: Análise exporatória de dados do Legislativo
#
# * [Aula 02: Acessando os dados da CEAP via API](#Aula-02:-Acessando-os-dados-da-CEAP-via-API)
# * [Aula 03: Lendo os dados com Pandas](#Aula-03:-Lendo-os-dados-com-Pandas)
#     * [Dicionário de dados](#Dicionário-de-Dados)
# * [Aula 04: Organizando e visualizando os dados](#Aula-04:-Organizando-e-visualizando-os-dados)
#     * [Informando tipos na leitura dos dados](#Informando-tipos-na-leitura-dos-dados)
#     * [Preenchendo valores nulos](#Preenchendo-valores-nulos)
#     * [Sugestões de transformações](#Sugestões-de-transformações)
# * [Aula 07: Dados da Receita Federal](#Aula-07:-Dados-da-Receita-Federal)

# %% [markdown]
# ---

# %% [markdown]
# ## Aula 02: Acessando os dados da CEAP via API

# %% [markdown]
# Para baixar os arquivos das despesas pela **Cota para Exercício da Atividade Parlamentar** (CEAP), podemos utilizar a API da Câmara Legislativa. Os arquivos de cada ano estão disponíveis via URLs no formato `http://www.camara.leg.br/cotas/Ano-{ano}.{formato}[.zip]`.
#
# Você pode encontrar mais detalhes na [documentação dos dados sobre Despesas pela Cota para Exercício da Atividade Parlamentar](https://dadosabertos.camara.leg.br/swagger/api.html#staticfile).
#
# Há diversas formas de fazer o download dos arquivos usando Python. Para esse tutorial, vamos usar o pacote `requests`.

# %%
url = f"http://www.camara.leg.br/cotas/Ano-2019.csv.zip"

# %%
# pip show requests # mostrar se a biblioteca requests está instalada
# Out:
# Name: requests
# Version: 2.31.0
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache 2.0
# Location: c:\Users\gm_bi\Documents\GitHub\Escola_de_Dados\python-inovacao-civica\env\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: ydata-profiling
# ---
# Name: requests
# Version: 2.31.0
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache 2.0
# Location: c:\Users\gm_bi\Documents\GitHub\Escola_de_Dados\python-inovacao-civica\env\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: ydata-profiling
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: #, a, biblioteca, está, instalada, mostrar, se

# %%
import requests

# fazendo o download do conteúdo do arquivo
r = requests.get(url)

# %%
# abrindo um arquivo no seu computador
file = open(f"Ano-2019.csv.zip", "wb")

# escrever o conteúdo
file.write(r.content)
file.close()

# %%
# outra forma de criar arquivos, e escrever conteúdo

# with open(f"Ano-{year}.csv.zip", "wb") as code:
#    code.write(r.content)

# %% [markdown]
# Como o arquivo baixado pela API é um arquivo zip, vamos precisar descompatar. Vamos usar o `zipfile`, um módulo que nos dá ferramentas para diversas manipulações de arquivos zipados.

# %%
from zipfile import ZipFile

# %%
zip_file = ZipFile(f"Ano-2019.csv.zip", "r")

# %%
zip_file.namelist()
# Out:
# ['Ano-2019.csv']

# %%
zip_file.extract(member=f"Ano-2019.csv", path=f"reembolso-2019")
# Out:
# 'reembolso-2019\\Ano-2019.csv'

# %%
# caso a gente queira extrair todo o conteúdo do arquivo zip (descomentar a linha a seguir)

# zip_file.extractall(path=f"reimbursements-{year}")

# %%
zip_file.close()

# %% [markdown]
# ### Documentações para consulta
#
# 1. requests - [Documentação](https://requests.readthedocs.io/en/latest/)
# 2. zipfile - [Documentação](https://docs.python.org/pt-br/3/library/zipfile.html)

# %% [markdown]
# ## Aula 03: Lendo os dados com Pandas

# %%
import pandas as pd

pd.set_option("display.max_columns", None)  # Configuração para ajuda na legibilidade das tabelas

# %%
pd.read_csv("reembolso-2019/Ano-2019.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pd.read_csv("reembolso-2019/Ano-2019.csv")
#
# File c:\Users\gm_bi\Documents\GitHub\Escola_de_Dados\python-inovacao-civica\env\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\gm_bi\Documents\GitHub\Escola_de_Dados\python-inovacao-civica\env\Lib\site-packages\pandas\io\parsers\readers.py:583, in _read(filepath_or_buffer, kwds)
#     580     return parser
#     582 with parser:
# --> 583     return parser.read(nrows)
#
# File c:\Users\gm_bi\Documents\GitHub\Escola_de_Dados\python-inovacao-civica\env\Lib\site-packages\pandas\io\parsers\readers.py:1704, in TextFileReader.read(self, nrows)
#    1697 nrows = validate_integer("nrows", nrows)
#    1698 try:
#    1699     # error: "ParserBase" has no attribute "read"
#    1700     (
#    1701         index,
#    1702         columns,
#    1703         col_dict,
# -> 1704     ) = self._engine.read(  # type: ignore[attr-defined]
#    1705         nrows
#    1706     )
#    1707 except Exception:
#    1708     self.close()
#
# File c:\Users\gm_bi\Documents\GitHub\Escola_de_Dados\python-inovacao-civica\env\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File c:\Users\gm_bi\Documents\GitHub\Escola_de_Dados\python-inovacao-civica\env\Lib\site-packages\pandas\_libs\parsers.pyx:812, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File c:\Users\gm_bi\Documents\GitHub\Escola_de_Dados\python-inovacao-civica\env\Lib\site-packages\pandas\_libs\parsers.pyx:873, in pandas._libs.parsers.TextReader._read_rows()
#
# File c:\Users\gm_bi\Documents\GitHub\Escola_de_Dados\python-inovacao-civica\env\Lib\site-packages\pandas\_libs\parsers.pyx:848, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File c:\Users\gm_bi\Documents\GitHub\Escola_de_Dados\python-inovacao-civica\env\Lib\site-packages\pandas\_libs\parsers.pyx:859, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File c:\Users\gm_bi\Documents\GitHub\Escola_de_Dados\python-inovacao-civica\env\Lib\site-packages\pandas\_libs\parsers.pyx:2025, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 116, saw 2

# %% [markdown]
# Opa! Erro na leitura do nosso arquivo. Quando encontramos esse erro na leitura de um arquivo, existe algumas possíveis causas mais comuns, uma delas é que o caracter que separa as colunas pode não ser o que o `read_csv` espera.
#
# Encontre na [documentação do read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) qual o separador considerado padrão e depois confira no arquivo qual o separador que é utilizado.
#
# Agora, modifique a próxima célula com o que você acha que deve ser feito para que a leitura do csv aconteça sem erros.

# %%
df_reembolso = pd.read_csv("reembolso-2019/Ano-2019.csv", sep=";")
# sep == delimiter

# %% [markdown]
# Vamos visualizar as 5 primeiras linhas do nosso Dataframe.

# %%
df_reembolso.head()
# Out:
#   txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# 0        LID.GOV-CD  NaN          NaN                    NaN           2015
# 1        LID.GOV-CD  NaN          NaN                    NaN           2019
# 2        LID.GOV-CD  NaN          NaN                    NaN           2019
# 3        LID.GOV-CD  NaN          NaN                    NaN           2019
# 4        LID.GOV-CD  NaN          NaN                    NaN           2019
#
#   sgUF sgPartido  codLegislatura  numSubCota  \
# 0  NaN       NaN              55          13
# 1  NaN       NaN              56          13
# 2  NaN       NaN              56          13
# 3  NaN       NaN              56          13
# 4  NaN       NaN              56          13
#
#                                  txtDescricao  numEspecificacaoSubCota  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 2  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 3  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 4  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
#
#   txtDescricaoEspecificacao                          txtFornecedor  \
# 0                       NaN                 CRISTIANE FERREIRA EPP
# 1                       NaN                 CRISTIANE FERREIRA EPP
# 2                       NaN                 CRISTIANE FERREIRA EPP
# 3                       NaN                 CRISTIANE FERREIRA EPP
# 4                       NaN  PANIFICADORA FERREIRA NETO LTDA - EPP
#
#            txtCNPJCPF txtNumero  indTipoDocumento           datEmissao  \
# 0  037.139.030/0010-8       693                 4  2019-01-16T00:00:00
# 1  037.139.030/0010-8       716                 4  2019-02-04T00:00:00
# 2  037.139.030/0010-8       723                 4  2019-02-25T00:00:00
# 3  037.139.030/0010-8       753                 4  2019-03-28T00:00:00
# 4  037.139.030/0010-8       791                 4  2019-05-07T00:00:00
#
#    vlrDocumento  vlrGlosa  vlrLiquido  numMes  numAno  numParcela  \
# 0        111.30       0.0      111.30       1    2019           0
# 1        117.19       0.0      117.19       2    2019           0
# 2        120.15       0.0      120.15       2    2019           0
# 3        151.18       0.0      151.18       3    2019           0
# 4        119.90       0.0      119.90       5    2019           0
#
#   txtPassageiro txtTrecho  numLote  numRessarcimento datPagamentoRestituicao  \
# 0           NaN       NaN  1554246               NaN                     NaN
# 1           NaN       NaN  1570078               NaN                     NaN
# 2           NaN       NaN  1570503               NaN                     NaN
# 3           NaN       NaN  1579375               NaN                     NaN
# 4           NaN       NaN  1590980               NaN                     NaN
#
#    vlrRestituicao  nuDeputadoId  ideDocumento  \
# 0             NaN          2812       6738121
# 1             NaN          2812       6769606
# 2             NaN          2812       6771099
# 3             NaN          2812       6793690
# 4             NaN          2812       6821674
#
#                                         urlDocumento
# 0  https://www.camara.leg.br/cota-parlamentar/not...
# 1  https://www.camara.leg.br/cota-parlamentar/not...
# 2  https://www.camara.leg.br/cota-parlamentar/not...
# 3  https://www.camara.leg.br/cota-parlamentar/not...
# 4  https://www.camara.leg.br/cota-parlamentar/not...

# %% [markdown]
# #### Como podemos fazer para visualizar as 10 primeiras linhas?
#
# *Escreva e rode o código na célula abaixo.*

# %%
df_reembolso.head(10)
# Out:
#   txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# 0        LID.GOV-CD  NaN          NaN                    NaN           2015
# 1        LID.GOV-CD  NaN          NaN                    NaN           2019
# 2        LID.GOV-CD  NaN          NaN                    NaN           2019
# 3        LID.GOV-CD  NaN          NaN                    NaN           2019
# 4        LID.GOV-CD  NaN          NaN                    NaN           2019
# 5        LID.GOV-CD  NaN          NaN                    NaN           2019
# 6        LID.GOV-CD  NaN          NaN                    NaN           2019
# 7        LID.GOV-CD  NaN          NaN                    NaN           2019
# 8        LID.GOV-CD  NaN          NaN                    NaN           2019
# 9        LID.GOV-CD  NaN          NaN                    NaN           2019
#
#   sgUF sgPartido  codLegislatura  numSubCota  \
# 0  NaN       NaN              55          13
# 1  NaN       NaN              56          13
# 2  NaN       NaN              56          13
# 3  NaN       NaN              56          13
# 4  NaN       NaN              56          13
# 5  NaN       NaN              56          13
# 6  NaN       NaN              56          13
# 7  NaN       NaN              56          13
# 8  NaN       NaN              56          13
# 9  NaN       NaN              56          13
#
#                                  txtDescricao  numEspecificacaoSubCota  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 2  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 3  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 4  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 5  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 6  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 7  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 8  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 9  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
#
#   txtDescricaoEspecificacao                          txtFornecedor  \
# 0                       NaN                 CRISTIANE FERREIRA EPP
# 1                       NaN                 CRISTIANE FERREIRA EPP
# 2                       NaN                 CRISTIANE FERREIRA EPP
# 3                       NaN                 CRISTIANE FERREIRA EPP
# 4                       NaN  PANIFICADORA FERREIRA NETO LTDA - EPP
# 5                       NaN  PANIFICADORA FERREIRA NETO LTDA - EPP
# 6                       NaN             ROBERTTH MOREIRA DE JESUS.
# 7                       NaN               SILT SELF SERVICE EIRELI
# 8                       NaN            SILT SELF SERVICE EIRELI ME
# 9                       NaN            SILT SELF SERVICE EIRELI ME
#
#            txtCNPJCPF  txtNumero  indTipoDocumento           datEmissao  \
# 0  037.139.030/0010-8        693                 4  2019-01-16T00:00:00
# 1  037.139.030/0010-8        716                 4  2019-02-04T00:00:00
# 2  037.139.030/0010-8        723                 4  2019-02-25T00:00:00
# 3  037.139.030/0010-8        753                 4  2019-03-28T00:00:00
# 4  037.139.030/0010-8        791                 4  2019-05-07T00:00:00
# 5  037.139.030/0010-8        849                 4  2019-06-04T00:00:00
# 6  305.615.740/0010-8  001209354                 0  2019-02-21T00:00:00
# 7  072.867.310/0019-4        688                 4  2019-11-07T23:00:00
# 8  072.867.310/0019-4        271                 4  2019-03-01T00:00:00
# 9  072.867.310/0019-4        323                 4  2019-05-02T00:00:00
#
#    vlrDocumento  vlrGlosa  vlrLiquido  numMes  numAno  numParcela  \
# 0        111.30       0.0      111.30       1    2019           0
# 1        117.19       0.0      117.19       2    2019           0
# 2        120.15       0.0      120.15       2    2019           0
# 3        151.18       0.0      151.18       3    2019           0
# 4        119.90       0.0      119.90       5    2019           0
# 5        151.54       0.0      151.54       6    2019           0
# 6        500.00       0.0      500.00       2    2019           0
# 7       1079.28       0.0     1079.28      10    2019           0
# 8        440.19       0.0      440.19       3    2019           0
# 9        503.02       0.0      503.02       4    2019           0
#
#   txtPassageiro txtTrecho  numLote  numRessarcimento datPagamentoRestituicao  \
# 0           NaN       NaN  1554246               NaN                     NaN
# 1           NaN       NaN  1570078               NaN                     NaN
# 2           NaN       NaN  1570503               NaN                     NaN
# 3           NaN       NaN  1579375               NaN                     NaN
# 4           NaN       NaN  1590980               NaN                     NaN
# 5           NaN       NaN  1602364               NaN                     NaN
# 6           NaN       NaN  1570291               NaN                     NaN
# 7           NaN       NaN  1651234               NaN                     NaN
# 8           NaN       NaN  1572257               NaN                     NaN
# 9           NaN       NaN  1589408               NaN                     NaN
#
#    vlrRestituicao  nuDeputadoId  ideDocumento  \
# 0             NaN          2812       6738121
# 1             NaN          2812       6769606
# 2             NaN          2812       6771099
# 3             NaN          2812       6793690
# 4             NaN          2812       6821674
# 5             NaN          2812       6846469
# 6             NaN          2812       6770386
# 7             NaN          2812       6959086
# 8             NaN          2812       6775373
# 9             NaN          2812       6818391
#
#                                         urlDocumento
# 0  https://www.camara.leg.br/cota-parlamentar/not...
# 1  https://www.camara.leg.br/cota-parlamentar/not...
# 2  https://www.camara.leg.br/cota-parlamentar/not...
# 3  https://www.camara.leg.br/cota-parlamentar/not...
# 4  https://www.camara.leg.br/cota-parlamentar/not...
# 5  https://www.camara.leg.br/cota-parlamentar/not...
# 6  https://www.camara.leg.br/cota-parlamentar/doc...
# 7  https://www.camara.leg.br/cota-parlamentar/not...
# 8  https://www.camara.leg.br/cota-parlamentar/not...
# 9  https://www.camara.leg.br/cota-parlamentar/not...

# %% [markdown]
# Podemos também recuperar uma amosta aleatória do nosso Dataframe. Para isso, usamos o [`sample`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_reembolso.sample()
# Out:
#            txNomeParlamentar           cpf  ideCadastro  \
# 134720  Evair Vieira de Melo  2.261266e+09     178871.0
#
#         nuCarteiraParlamentar  nuLegislatura sgUF sgPartido  codLegislatura  \
# 134720                  274.0           2019   ES        PP              56
#
#         numSubCota          txtDescricao  numEspecificacaoSubCota  \
# 134720         999  PASSAGEM AÉREA - RPA                        0
#
#        txtDescricaoEspecificacao    txtFornecedor          txtCNPJCPF  \
# 134720                       NaN  Cia Aérea - TAM  020.128.620/0016-0
#
#                        txtNumero  indTipoDocumento           datEmissao  \
# 134720  Bilhete: 957-2110.776287                 0  2019-09-16T00:00:00
#
#         vlrDocumento  vlrGlosa  vlrLiquido  numMes  numAno  numParcela  \
# 134720        335.57       0.0      335.57       9    2019           0
#
#                txtPassageiro txtTrecho  numLote  numRessarcimento  \
# 134720  Evair Vieira de Melo   BSB/VIX        0               0.0
#
#        datPagamentoRestituicao  vlrRestituicao  nuDeputadoId  ideDocumento  \
# 134720                     NaN             NaN          2984       1703939
#
#        urlDocumento
# 134720          NaN

# %% [markdown]
# #### Como podemos fazer para visualizar 5 amostras aleatórias?
#
# *Escreva e rode o código na célula abaixo.*

# %%
df_reembolso.sample(5)
# Out:
#        txNomeParlamentar           cpf  ideCadastro  nuCarteiraParlamentar  \
# 260774       Pinheirinho  1.062782e+10     204524.0                  261.0
# 192304         Elias Vaz  4.228944e+10     204389.0                  423.0
# 50624    Gleisi Hoffmann  6.767706e+10     107283.0                  451.0
# 162881  Herculano Passos  5.516329e+08     178981.0                  362.0
# 224788    Gutemberg Reis  7.733342e+09     204456.0                  302.0
#
#         nuLegislatura sgUF     sgPartido  codLegislatura  numSubCota  \
# 260774           2019   MG            PP              56         122
# 192304           2019   GO           PSB              56         122
# 50624            2019   PR            PT              56           3
# 162881           2019   SP  REPUBLICANOS              56          13
# 224788           2019   RJ           MDB              56           1
#
#                                              txtDescricao  \
# 260774          SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO
# 192304          SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO
# 50624                       COMBUSTÍVEIS E LUBRIFICANTES.
# 162881         FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 224788  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
#
#         numEspecificacaoSubCota txtDescricaoEspecificacao  \
# 260774                        0                       NaN
# 192304                        0                       NaN
# 50624                         1      Veículos Automotores
# 162881                        0                       NaN
# 224788                        0                       NaN
#
#                                            txtFornecedor          txtCNPJCPF  \
# 260774                                         SINPETAXI  000.317.080/0010-0
# 192304                   UBER DO BRASIL TECNOLOGIA LTDA.  178.956.460/0018-7
# 50624                      POSTO DE GASOLINA HELLER LTDA  850.960.970/0013-0
# 162881  SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC  334.691.720/0067-2
# 224788                           PLACAR IMOBILIARIA LTDA  279.528.370/0019-7
#
#        txtNumero  indTipoDocumento           datEmissao  vlrDocumento  \
# 260774      2733                 1  2019-06-18T00:00:00         29.00
# 192304       S/N                 1  2019-09-10T00:00:00          6.12
# 50624     130426                 4  2019-06-29T00:00:00        115.00
# 162881     22813                 4  2019-07-09T00:00:00         28.49
# 224788  10362019                 1  2019-06-21T00:00:00       6081.12
#
#         vlrGlosa  vlrLiquido  numMes  numAno  numParcela txtPassageiro  \
# 260774      0.00       29.00       6    2019           0           NaN
# 192304      1.00        5.12       9    2019           0           NaN
# 50624     105.09        9.91       6    2019           0           NaN
# 162881      0.00       28.49       7    2019           0           NaN
# 224788      5.70     6075.42       7    2019           0           NaN
#
#        txtTrecho  numLote  numRessarcimento datPagamentoRestituicao  \
# 260774       NaN  1607386               NaN                     NaN
# 192304       NaN  1650964               NaN                     NaN
# 50624        NaN  1615809               NaN                     NaN
# 162881       NaN  1627542               NaN                     NaN
# 224788       NaN  1609904               NaN                     NaN
#
#         vlrRestituicao  nuDeputadoId  ideDocumento  \
# 260774             NaN          3260       6857866
# 192304             NaN          3400       6958276
# 50624              NaN          3430       6878302
# 162881             NaN          2976       6905438
# 224788             NaN          3210       6864446
#
#                                              urlDocumento
# 260774  https://www.camara.leg.br/cota-parlamentar/doc...
# 192304  https://www.camara.leg.br/cota-parlamentar/doc...
# 50624   https://www.camara.leg.br/cota-parlamentar/not...
# 162881  https://www.camara.leg.br/cota-parlamentar/not...
# 224788  https://www.camara.leg.br/cota-parlamentar/doc...

# %% [markdown]
# ### Dicionário de Dados

# %% [markdown]
# Um passo importante para dar antes de começar a análisar é **entender os dados que estamos manipulando**.
#
# *Sempre procure o significado dos campos, procure entender quais os tipos de dados preenchem aquele campo. São dados numéricos? São caracteres? Não palavras usadas para categorizar/classificar os dados?*

# %% [markdown]
# | Elemento de Dado          | Nome do Dado                           | Definição do Dado                                                                                                                                                                                                                                                                                                                                                                                                                   |   |   |
# |---------------------------|----------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---|---|
# | txNomeParlamentar         | Nome Parlamentar                       | Nome adotado pelo Parlamentar ao tomar posse do seu mandato. Compõe-se de dois elementos: um prenome e o nome; dois nomes; ou dois prenomes, salvo, a juízo do Presidente da Casa legislativa, que poderá alterar essa regra para que não ocorram confusões.                                                                                                                                                                        |   |   |
# | ideCadastro               | Identificador Único do Parlamentar     | Número que identifica unicamente um deputado federal na CD.                                                                                                                                                                                                                                                                                                                                                                         |   |   |
# | nuCarteiraParlamentar     | Número da  Carteira Parlamentar        | Documento usado para identificar um deputado federal na CD. Pode alterar a cada Legislatura nova.                                                                                                                                                                                                                                                                                                                                   |   |   |
# | nuLegislatura             | Número da  Legislatura                 | No contexto da cota CEAP, representa o ano base de início da legislatura e é utilizado para compor a Carteira Parlamentar, pois esta poderá ser alterada à medida que se muda de Legislatura.                                                                                                                                     |   |   |
# | sgUF                      | Sigla da UF                            | No contexto da cota CEAP, representa a unidade da federação pela qual o deputado foi eleito e é utilizada para definir o valor da cota a que o deputado tem.                                                                                                                                                                                                                                                                        |   |   |
# | sgPartido                 | Sigla do Partido                       | O seu conteúdo representa a sigla de um partido. Tem personalidade jurídica de direito privado e goza de autonomia e liberdade no que diz respeito à criação, organização e funcionamento, observados os princípios e preceitos constitucionais. |   |   |
# | codLegislatura            | Código da Legislatura                  | No contexto da cota CEAP, o seu conteúdo representa o código identificador da Legislatura, que um número ordinal sequencial, alterado de um em um, a cada início de uma nova Legislatura (por exemplo, a Legislatura que iniciou em 2011 é a 54ª Legislatura).                                                                    |   |   |
# | numSubCota                | Número da Subcota                      | No contexto da Cota CEAP, o conteúdo deste dado representa o código do Tipo de Despesa referente à despesa realizada pelo deputado e comprovada por meio da emissão de um documento fiscal, a qual é debitada na cota do deputado.                                                                                                                                                                                                  |   |   |
# | txtDescricao              | Descrição da Subcota                   | O seu conteúdo é a descrição do Tipo de Despesa relativo à despesa em questão.                                                                                                                                                                                                                                                                                                                                                      |   |   |
# | numEspecificacaoSubCota   | Número da Especificação da Subcota     | No contexto da Cota CEAP, há despesas cujo Tipo de Despesa necessita ter uma especificação mais detalhada (por exemplo, “Combustível”). O conteúdo deste dado representa o código desta especificação mais detalhada.                                                                                                                                                                                                               |   |   |
# | txtDescricaoEspecificacao | Descrição da Especificação da Subcota  | Representa a descrição  especificação mais detalhada de um referido Tipo de Despesa.                                                                                                                                                                                                                                                                                                                                                |   |   |
# | txtFornecedor             | Fornecedor                             | O conteúdo deste dado representa o nome do fornecedor do produto ou serviço presente no documento fiscal                                                                                                                                                                                                                                                                                                                            |   |   |
# | txtCNPJCPF                | CNPJ/CPF                               | O conteúdo deste dado representa o CNPJ ou o CPF do emitente do documento fiscal, quando se tratar do uso da cota em razão do reembolso despesas comprovadas pela emissão de documentos fiscais.                                                                                                                                                                                                                                    |   |   |
# | txtNumero                 | Número do Documento                    | O conteúdo deste dado representa o número de face do documento fiscal emitido ou o número do documento que deu causa à despesa debitada na cota do deputado.                                                                                                                                                                                                                                                                        |   |   |
# | indTipoDocumento          | Indicativo de Tipo de Documento Fiscal | Este dado representa o tipo de documento do fiscal – 0 (Zero), para Nota Fiscal; 1 (um), para Recibo; e 2, para Despesa no Exterior.                                                                                                                                                                                                                                                                                                |   |   |
# | datEmissao                | Data de Emissão                        | O conteúdo deste dado é a data de emissão do documento fiscal ou a data do documento que tenha dado causa à despesa.                                                                                                                                                                                                                                                                                                                |   |   |
# | vlrDocumento              | Valor do Documento                     | O seu conteúdo é o valor de face do documento fiscal ou o valor do documento que deu causa à despesa. Quando se tratar de bilhete aéreo, esse valor poderá ser negativo, significando que o referido bilhete é um bilhete de compensação, pois compensa um outro bilhete emitido e não utilizado pelo deputado (idem para o dado vlrLiquido abaixo).                                                                                |   |   |
# | vlrGlosa                  | Valor da Glosa                         | O seu conteúdo representa o valor da glosa do documento fiscal que incidirá sobre o Valor do Documento, ou o valor da glosa do documento que deu causa à despesa.                                                                                                                                                                                                                                                                   |   |   |
# | vlrLiquido                | Valor Líquido                          | O seu conteúdo representa o valor líquido do documento fiscal ou do documento que deu causa à despesa e será calculado pela diferença entre o Valor do Documento e o Valor da Glosa. É este valor que será debitado da cota do deputado. Caso o débito seja do Tipo Telefonia e o valor seja igual a zero, significa que a despesa foi franqueada.                                                                                  |   |   |
# | numMes                    | Mês                                    | O seu conteúdo representa o Mês da competência financeira do documento fiscal ou do documento que deu causa à despesa. É utilizado, junto com o ano, para determinar em que período o débito gerará efeito financeiro sobre a cota.                                                                                                                                                                                                 |   |   |
# | numAno                    | Ano                                    | O seu conteúdo representa o Ano da competência financeira do documento fiscal ou do documento que deu causa à despesa. É utilizado, junto com o mês, para determinar em que período o débito gerará efeito financeiro sobre a cota.                                                                                                                                                                                                 |   |   |
# | numParcela                | Número da Parcela                      | O seu conteúdo representa o número da parcela do documento fiscal. Ocorre quando o documento tem de ser reembolsado de forma parcelada.                                                                                                                                                                                                                                                                                             |   |   |
# | txtPassageiro             | Passageiro                             | O conteúdo deste dado representa o nome do passageiro, quando o documento que deu causa à despesa se tratar de emissão de bilhete aéreo.                                                                                                                                                                                                                                                                                            |   |   |
# | txtTrecho                 | Trecho                                 | O conteúdo deste dado representa o trecho da viagem, quando o documento que deu causa à despesa se tratar de emissão de bilhete aéreo.                                                                                                                                                                                                                                                                                              |   |   |
# | numLote                   | Número do Lote                         | No contexto da Cota CEAP, o Número do Lote representa uma capa de lote que agrupa os documentos que serão entregues à Câmara para serem ressarcidos. Este dado, juntamente com o Número do Ressarcimento, auxilia a localização do documento no Arquivo da Casa.                                                                                                                                                                    |   |   |
# | numRessarcimento          | Número do Ressarcimento                | No contexto da Cota CEAP, o Número do Ressarcimento indica o ressarcimento do qual o documento fez parte por ocasião do processamento do seu reembolso. Este dado, juntamente com o Valor da Restituição, auxilia a localização do documento no Arquivo da Casa.                                                                                                                                                                 |   |   |
# |  vlrRestituicao           |  Valor da Restituição                  |  O seu conteúdo representa o valor restituído do documento fiscal que incidirá sobre o Valor do Documento.                                                                                                                                                                                                                                                                                                                          |   |   |
# | nuDeputadoId              | Identificador do Solicitante           | Número que identifica um Parlamentar ou Liderança na Transparência da Cota para Exercício da Atividade Parlamentar.                                                                                                                                                                                                                                                                                                                 |   |   |
#
#
# Legislatura: Período de quatro anos coincidente com o mandato parlamentar dos Deputados Federais.
#
# Definição de partido: é uma organização formada por pessoas com interesse ou ideologia comuns, que se associam com o fim de assumir o poder para implantar um programa de governo.
#
# *Fonte*: [EXPLICAÇÕES SOBRE O FORMATO DOS ARQUIVOS XML](https://www2.camara.leg.br/transparencia/cota-para-exercicio-da-atividade-parlamentar/explicacoes-sobre-o-formato-dos-arquivos-xml)

# %% [markdown]
# > Quais perguntas poderíamos responder com esses dados? E quais campos poderíamos utilizar?
# Compartilhe com os outros alunos no grupo da disciplina no Discord.

# %% [markdown]
# ## Aula 04: Organizando e visualizando os dados

# %% [markdown]
# ### Informando tipos na leitura dos dados
#
# Quando trabalhamos com pandas, é sempre interessante entender que tipos de dados estão contidos em cada coluna. Na leitura do arquivo podemos aproveitar para deixar isso configurado.
#
# Isso pode ser extramamente útil quando estamos lendo dados que contém informação sobre documentos, como CPF. Nesses casos podemos ter algo como `091777777`, se esse valor por lido como um número, ele vai virar `91777777`, já que não existe número que inicie com 0. Esse é um ótimo exemplo de dado que deve ser lido como um string, para que ele seja preservado ao máximo.
#
# Agora, sabendo quais dados nosso dataframe possui, vamos definir o tipo para cada um.

# %%
DTYPE = {
    "txNomeParlamentar": str,
    "ideCadastro": str,
    "nuCarteiraParlamentar": str,
    "nuLegislatura": str,
    "sgUF": str,
    "sgPartido": str,
    "codLegislatura": str,
    "numSubCota": str,
    "txtDescricao": str,
    "numEspecificacaoSubCota": str,
    "txtDescricaoEspecificacao": str,
    "txtFornecedor": str,
    "txtCNPJCPF": str,
    "txtNumero": str,
    "indTipoDocumento": str,
    "datEmissao": str,
    "vlrDocumento": float,
    "vlrGlosa": str,
    "vlrLiquido": float,
    "numMes": str,
    "numAno": str,
    "numParcela": str,
    "txtPassageiro": str,
    "txtTrecho": str,
    "numLote": str,
    "numRessarcimento": str,
    "nuDeputadoId": str,
    "ideDocumento": str,
}

df_reembolso = pd.read_csv(
    "reembolso-2019/Ano-2019.csv", delimiter=";", dtype=DTYPE, low_memory=False
)

# %% [markdown]
# Opa! Você lembra qual método podemos usar para conferir os tipos de cada coluna?
#
# **dica**: já passamos por esse método...

# %%
df_reembolso.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289453 entries, 0 to 289452
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   txNomeParlamentar          289453 non-null  object
#  1   cpf                        288449 non-null  float64
#  2   ideCadastro                288548 non-null  object
#  3   nuCarteiraParlamentar      288548 non-null  object
#  4   nuLegislatura              289453 non-null  object
#  5   sgUF                       288548 non-null  object
#  6   sgPartido                  288548 non-null  object
#  7   codLegislatura             289453 non-null  object
#  8   numSubCota                 289453 non-null  object
#  9   txtDescricao               289453 non-null  object
#  10  numEspecificacaoSubCota    289453 non-null  object
#  11  txtDescricaoEspecificacao  64765 non-null   object
#  12  txtFornecedor              289438 non-null  object
#  13  txtCNPJCPF                 285380 non-null  object
#  14  txtNumero                  289453 non-null  object
#  15  indTipoDocumento           289453 non-null  object
#  16  datEmissao                 283281 non-null  object
#  17  vlrDocumento               289453 non-null  float64
#  18  vlrGlosa                   289453 non-null  object
#  19  vlrLiquido                 289453 non-null  float64
#  20  numMes                     289453 non-null  object
#  21  numAno                     289453 non-null  object
#  22  numParcela                 289453 non-null  object
#  23  txtPassageiro              86363 non-null   object
#  24  txtTrecho                  85655 non-null   object
#  25  numLote                    289453 non-null  object
#  26  numRessarcimento           111948 non-null  object
#  27  datPagamentoRestituicao    222 non-null     object
#  28  vlrRestituicao             257 non-null     float64
#  29  nuDeputadoId               289453 non-null  object
#  30  ideDocumento               289453 non-null  object
#  31  urlDocumento               167781 non-null  object
# dtypes: float64(4), object(28)
# memory usage: 70.7+ MB

# %% [markdown]
# #### astype

# %%
# df_reembolso["ideCadastro"] = df_reembolso["ideCadastro"].astype('string')

# %% [markdown]
# Vamos conhecer mais algumas operações que podem nos ajudar a visualizar e entender nossos dados.

# %%
df_reembolso.tail()
# Out:
#        txNomeParlamentar           cpf ideCadastro nuCarteiraParlamentar  \
# 289448       Dr. Gonçalo  5.461154e+09      212625                   548
# 289449      Marcão Gomes  9.300886e+09      212749                   551
# 289450      Marcão Gomes  9.300886e+09      212749                   551
# 289451      Marcão Gomes  9.300886e+09      212749                   551
# 289452      Marcão Gomes  9.300886e+09      212749                   551
#
#        nuLegislatura sgUF     sgPartido codLegislatura numSubCota  \
# 289448          2019   MA  REPUBLICANOS             56        999
# 289449          2019   RJ            PL             56          1
# 289450          2019   RJ            PL             56          9
# 289451          2019   RJ            PL             56         10
# 289452          2019   RJ            PL             56        120
#
#                                              txtDescricao  \
# 289448                               PASSAGEM AÉREA - RPA
# 289449  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 289450                         PASSAGEM AÉREA - REEMBOLSO
# 289451                                          TELEFONIA
# 289452      LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES
#
#        numEspecificacaoSubCota txtDescricaoEspecificacao  \
# 289448                       0                       NaN
# 289449                       0                       NaN
# 289450                       0                       NaN
# 289451                       0                       NaN
# 289452                       0                       NaN
#
#                      txtFornecedor          txtCNPJCPF  \
# 289448             Cia Aérea - TAM  020.128.620/0016-0
# 289449  LUIZ FELIPE GOULART MARINS   007.227.727/00  -
# 289450              LATAM AIRLINES  020.128.620/0016-0
# 289451                       RAMAL  000.000.000/0000-6
# 289452   CARRY SERVIÇOS E LOCAÇÕES  096.026.750/0018-5
#
#                        txtNumero indTipoDocumento           datEmissao  \
# 289448  Bilhete: 957-2119.806995                0  2019-12-11T00:00:00
# 289449                       S/N                1  2019-12-31T00:00:00
# 289450             9572120411039                0  2019-12-18T00:00:00
# 289451                   6992781                0                  NaN
# 289452                      0035                0  2020-01-31T00:00:00
#
#         vlrDocumento vlrGlosa  vlrLiquido numMes numAno numParcela  \
# 289448       1930.57        0     1930.57     12   2019          0
# 289449        233.00        0      233.00     12   2019          0
# 289450       1890.66        0     1890.66     12   2019          0
# 289451          1.19        0        1.19     12   2019          0
# 289452       1516.00        0     1516.00     12   2019          0
#
#        txtPassageiro txtTrecho  numLote numRessarcimento  \
# 289448   Dr. Gonçalo   BSB/THE        0                0
# 289449           NaN       NaN  1686035              NaN
# 289450           NaN       NaN  1667677              NaN
# 289451           NaN       NaN        0                0
# 289452           NaN       NaN  1680650              NaN
#
#        datPagamentoRestituicao  vlrRestituicao nuDeputadoId ideDocumento  \
# 289448                     NaN             NaN         3463      1722569
# 289449                     NaN             NaN         3465      7035691
# 289450                     NaN             NaN         3465      6995992
# 289451                     NaN             NaN         3465            0
# 289452                     NaN             NaN         3465      7022622
#
#                                              urlDocumento
# 289448                                                NaN
# 289449  https://www.camara.leg.br/cota-parlamentar/doc...
# 289450  https://www.camara.leg.br/cota-parlamentar/doc...
# 289451                                                NaN
# 289452  https://www.camara.leg.br/cota-parlamentar/doc...

# %%
df_reembolso.shape
# Out:
# (289453, 32)

# %%
df_reembolso.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289453 entries, 0 to 289452
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   txNomeParlamentar          289453 non-null  object
#  1   cpf                        288449 non-null  float64
#  2   ideCadastro                288548 non-null  string
#  3   nuCarteiraParlamentar      288548 non-null  object
#  4   nuLegislatura              289453 non-null  object
#  5   sgUF                       288548 non-null  object
#  6   sgPartido                  288548 non-null  object
#  7   codLegislatura             289453 non-null  object
#  8   numSubCota                 289453 non-null  object
#  9   txtDescricao               289453 non-null  object
#  10  numEspecificacaoSubCota    289453 non-null  object
#  11  txtDescricaoEspecificacao  64765 non-null   object
#  12  txtFornecedor              289438 non-null  object
#  13  txtCNPJCPF                 285380 non-null  object
#  14  txtNumero                  289453 non-null  object
#  15  indTipoDocumento           289453 non-null  object
#  16  datEmissao                 283281 non-null  object
#  17  vlrDocumento               289453 non-null  float64
#  18  vlrGlosa                   289453 non-null  object
#  19  vlrLiquido                 289453 non-null  float64
#  20  numMes                     289453 non-null  object
#  21  numAno                     289453 non-null  object
#  22  numParcela                 289453 non-null  object
#  23  txtPassageiro              86363 non-null   object
#  24  txtTrecho                  85655 non-null   object
#  25  numLote                    289453 non-null  object
#  26  numRessarcimento           111948 non-null  object
#  27  datPagamentoRestituicao    222 non-null     object
#  28  vlrRestituicao             257 non-null     float64
#  29  nuDeputadoId               289453 non-null  object
#  30  ideDocumento               289453 non-null  object
#  31  urlDocumento               167781 non-null  object
# dtypes: float64(4), object(27), string(1)
# memory usage: 70.7+ MB

# %%
df_reembolso.columns
# Out:
# Index(['txNomeParlamentar', 'cpf', 'ideCadastro', 'nuCarteiraParlamentar',
#        'nuLegislatura', 'sgUF', 'sgPartido', 'codLegislatura', 'numSubCota',
#        'txtDescricao', 'numEspecificacaoSubCota', 'txtDescricaoEspecificacao',
#        'txtFornecedor', 'txtCNPJCPF', 'txtNumero', 'indTipoDocumento',
#        'datEmissao', 'vlrDocumento', 'vlrGlosa', 'vlrLiquido', 'numMes',
#        'numAno', 'numParcela', 'txtPassageiro', 'txtTrecho', 'numLote',
#        'numRessarcimento', 'datPagamentoRestituicao', 'vlrRestituicao',
#        'nuDeputadoId', 'ideDocumento', 'urlDocumento'],
#       dtype='object')

# %% [markdown]
# ### Preenchendo valores nulos

# %% [markdown]
# #### 1. Substituir os valores nulos por "Não se aplica"

# %%
df_reembolso.fillna(value="Não se aplica").head()
# Out:
#   txNomeParlamentar            cpf    ideCadastro nuCarteiraParlamentar  \
# 0        LID.GOV-CD  Não se aplica  Não se aplica         Não se aplica
# 1        LID.GOV-CD  Não se aplica  Não se aplica         Não se aplica
# 2        LID.GOV-CD  Não se aplica  Não se aplica         Não se aplica
# 3        LID.GOV-CD  Não se aplica  Não se aplica         Não se aplica
# 4        LID.GOV-CD  Não se aplica  Não se aplica         Não se aplica
#
#   nuLegislatura           sgUF      sgPartido codLegislatura numSubCota  \
# 0          2015  Não se aplica  Não se aplica             55         13
# 1          2019  Não se aplica  Não se aplica             56         13
# 2          2019  Não se aplica  Não se aplica             56         13
# 3          2019  Não se aplica  Não se aplica             56         13
# 4          2019  Não se aplica  Não se aplica             56         13
#
#                                  txtDescricao numEspecificacaoSubCota  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 2  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 3  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 4  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
#
#   txtDescricaoEspecificacao                          txtFornecedor  \
# 0             Não se aplica                 CRISTIANE FERREIRA EPP
# 1             Não se aplica                 CRISTIANE FERREIRA EPP
# 2             Não se aplica                 CRISTIANE FERREIRA EPP
# 3             Não se aplica                 CRISTIANE FERREIRA EPP
# 4             Não se aplica  PANIFICADORA FERREIRA NETO LTDA - EPP
#
#            txtCNPJCPF txtNumero indTipoDocumento           datEmissao  \
# 0  037.139.030/0010-8       693                4  2019-01-16T00:00:00
# 1  037.139.030/0010-8       716                4  2019-02-04T00:00:00
# 2  037.139.030/0010-8       723                4  2019-02-25T00:00:00
# 3  037.139.030/0010-8       753                4  2019-03-28T00:00:00
# 4  037.139.030/0010-8       791                4  2019-05-07T00:00:00
#
#    vlrDocumento vlrGlosa  vlrLiquido numMes numAno numParcela  txtPassageiro  \
# 0        111.30        0      111.30      1   2019          0  Não se aplica
# 1        117.19        0      117.19      2   2019          0  Não se aplica
# 2        120.15        0      120.15      2   2019          0  Não se aplica
# 3        151.18        0      151.18      3   2019          0  Não se aplica
# 4        119.90        0      119.90      5   2019          0  Não se aplica
#
#        txtTrecho  numLote numRessarcimento datPagamentoRestituicao  \
# 0  Não se aplica  1554246    Não se aplica           Não se aplica
# 1  Não se aplica  1570078    Não se aplica           Não se aplica
# 2  Não se aplica  1570503    Não se aplica           Não se aplica
# 3  Não se aplica  1579375    Não se aplica           Não se aplica
# 4  Não se aplica  1590980    Não se aplica           Não se aplica
#
#   vlrRestituicao nuDeputadoId ideDocumento  \
# 0  Não se aplica         2812      6738121
# 1  Não se aplica         2812      6769606
# 2  Não se aplica         2812      6771099
# 3  Não se aplica         2812      6793690
# 4  Não se aplica         2812      6821674
#
#                                         urlDocumento
# 0  https://www.camara.leg.br/cota-parlamentar/not...
# 1  https://www.camara.leg.br/cota-parlamentar/not...
# 2  https://www.camara.leg.br/cota-parlamentar/not...
# 3  https://www.camara.leg.br/cota-parlamentar/not...
# 4  https://www.camara.leg.br/cota-parlamentar/not...

# %% [markdown]
# Caso deseje aplicar a sugestão de transformação, execute:

# %%
# df_reembolso = df_reembolso.fillna(value="Não se aplica")

# %% [markdown]
# #### 2. Filtrar por registros que estejam com a Sigla do Partido Nulos

# %%
df_reembolso[df_reembolso.sgPartido.isna()]
# Out:
#     txNomeParlamentar  cpf ideCadastro nuCarteiraParlamentar nuLegislatura  \
# 0          LID.GOV-CD  NaN        <NA>                   NaN          2015
# 1          LID.GOV-CD  NaN        <NA>                   NaN          2019
# 2          LID.GOV-CD  NaN        <NA>                   NaN          2019
# 3          LID.GOV-CD  NaN        <NA>                   NaN          2019
# 4          LID.GOV-CD  NaN        <NA>                   NaN          2019
# ..                ...  ...         ...                   ...           ...
# 900            LIDMIN  NaN        <NA>                   NaN          2019
# 901            LIDMIN  NaN        <NA>                   NaN          2019
# 902            LIDMIN  NaN        <NA>                   NaN          2019
# 903            LIDMIN  NaN        <NA>                   NaN          2019
# 904            LIDMIN  NaN        <NA>                   NaN          2019
#
#     sgUF sgPartido codLegislatura numSubCota  \
# 0    NaN       NaN             55         13
# 1    NaN       NaN             56         13
# 2    NaN       NaN             56         13
# 3    NaN       NaN             56         13
# 4    NaN       NaN             56         13
# ..   ...       ...            ...        ...
# 900  NaN       NaN             56         13
# 901  NaN       NaN             56         13
# 902  NaN       NaN             56         13
# 903  NaN       NaN             56         13
# 904  NaN       NaN             56         13
#
#                                    txtDescricao numEspecificacaoSubCota  \
# 0    FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 1    FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 2    FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 3    FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 4    FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# ..                                          ...                     ...
# 900  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 901  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 902  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 903  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 904  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
#
#     txtDescricaoEspecificacao                                   txtFornecedor  \
# 0                         NaN                          CRISTIANE FERREIRA EPP
# 1                         NaN                          CRISTIANE FERREIRA EPP
# 2                         NaN                          CRISTIANE FERREIRA EPP
# 3                         NaN                          CRISTIANE FERREIRA EPP
# 4                         NaN           PANIFICADORA FERREIRA NETO LTDA - EPP
# ..                        ...                                             ...
# 900                       NaN  SABORES DE BRASILIA COMERCIO DE ALIMENTOS LTDA
# 901                       NaN                     SILT SELF SERVICE EIRELI ME
# 902                       NaN                     SILT SELF SERVICE EIRELI ME
# 903                       NaN                     SILT SELF SERVICE EIRELI ME
# 904                       NaN                     SILT SELF SERVICE EIRELI ME
#
#              txtCNPJCPF txtNumero indTipoDocumento           datEmissao  \
# 0    037.139.030/0010-8       693                4  2019-01-16T00:00:00
# 1    037.139.030/0010-8       716                4  2019-02-04T00:00:00
# 2    037.139.030/0010-8       723                4  2019-02-25T00:00:00
# 3    037.139.030/0010-8       753                4  2019-03-28T00:00:00
# 4    037.139.030/0010-8       791                4  2019-05-07T00:00:00
# ..                  ...       ...              ...                  ...
# 900  216.856.000/0029-1     12223                4  2019-08-06T00:00:00
# 901  072.867.310/0019-4    026315                0  2019-12-01T23:00:00
# 902  072.867.310/0019-4    038129                0  2019-11-26T23:00:00
# 903  072.867.310/0019-4    038130                0  2019-11-26T23:00:00
# 904  072.867.310/0019-4     37602                4  2019-11-18T23:00:00
#
#      vlrDocumento vlrGlosa  vlrLiquido numMes numAno numParcela txtPassageiro  \
# 0          111.30        0      111.30      1   2019          0           NaN
# 1          117.19        0      117.19      2   2019          0           NaN
# 2          120.15        0      120.15      2   2019          0           NaN
# 3          151.18        0      151.18      3   2019          0           NaN
# 4          119.90        0      119.90      5   2019          0           NaN
# ..            ...      ...         ...    ...    ...        ...           ...
# 900        758.31    59.45      698.86      8   2019          0           NaN
# 901         63.46        0       63.46     12   2019          0           NaN
# 902        123.66        0      123.66     11   2019          0           NaN
# 903         95.98        0       95.98     11   2019          0           NaN
# 904         73.00        0       73.00     11   2019          0           NaN
#
#     txtTrecho  numLote numRessarcimento datPagamentoRestituicao  \
# 0         NaN  1554246              NaN                     NaN
# 1         NaN  1570078              NaN                     NaN
# 2         NaN  1570503              NaN                     NaN
# 3         NaN  1579375              NaN                     NaN
# 4         NaN  1590980              NaN                     NaN
# ..        ...      ...              ...                     ...
# 900       NaN  1618189              NaN                     NaN
# 901       NaN  1658394              NaN                     NaN
# 902       NaN  1658383              NaN                     NaN
# 903       NaN  1658375              NaN                     NaN
# 904       NaN  1652795              NaN                     NaN
#
#      vlrRestituicao nuDeputadoId ideDocumento  \
# 0               NaN         2812      6738121
# 1               NaN         2812      6769606
# 2               NaN         2812      6771099
# 3               NaN         2812      6793690
# 4               NaN         2812      6821674
# ..              ...          ...          ...
# 900             NaN         2806      6884032
# 901             NaN         2806      6976028
# 902             NaN         2806      6975999
# 903             NaN         2806      6975967
# 904             NaN         2806      6962818
#
#                                           urlDocumento
# 0    https://www.camara.leg.br/cota-parlamentar/not...
# 1    https://www.camara.leg.br/cota-parlamentar/not...
# 2    https://www.camara.leg.br/cota-parlamentar/not...
# 3    https://www.camara.leg.br/cota-parlamentar/not...
# 4    https://www.camara.leg.br/cota-parlamentar/not...
# ..                                                 ...
# 900  https://www.camara.leg.br/cota-parlamentar/not...
# 901  https://www.camara.leg.br/cota-parlamentar/doc...
# 902  https://www.camara.leg.br/cota-parlamentar/doc...
# 903  https://www.camara.leg.br/cota-parlamentar/doc...
# 904  https://www.camara.leg.br/cota-parlamentar/not...
#
# [905 rows x 32 columns]

# %% [markdown]
# Você pode nessa etapa decidir se gostaria de remover esses registros, renomear para outro valor com o `fillna`, entre outras coisas.
#
# Lembrando que essas verificações são importantes para conhecer mais os dados que você está trabalhando.

# %% [markdown]
# #### 3. Verificar se existem registros com o número de documento fiscal nulo

# %%
df_reembolso[df_reembolso["ideDocumento"].isnull()]
# Out:
# Empty DataFrame
# Columns: [txNomeParlamentar, cpf, ideCadastro, nuCarteiraParlamentar, nuLegislatura, sgUF, sgPartido, codLegislatura, numSubCota, txtDescricao, numEspecificacaoSubCota, txtDescricaoEspecificacao, txtFornecedor, txtCNPJCPF, txtNumero, indTipoDocumento, datEmissao, vlrDocumento, vlrGlosa, vlrLiquido, numMes, numAno, numParcela, txtPassageiro, txtTrecho, numLote, numRessarcimento, datPagamentoRestituicao, vlrRestituicao, nuDeputadoId, ideDocumento, urlDocumento]
# Index: []

# %% [markdown]
# Caso tenha registros nulos, definir o que será feito.
#
# Ações que poderiam ser realizadas: remover valores nulos, renomear valores nulos, verificar se ocorreu algum erro na leitura dos dados e etc.
#
# Fazer essas verificações é importante para conhecer mais os dados que estão sendo trabalhos.

# %% [markdown]
# ### Sugestões de transformações
#
# > As transformações são operações que fazemos que fazemos nos dados, para que eles fiquem utilizáveis.

# %% [markdown]
# #### 1. Converter a coluna de data de emissão que está como `str` para `datetime`
#
# Por default, o `to_datetime()` vai converter string no formato `MM/DD`, `MMDD` ou `MM-DD`. No nosso caso, as datas estão em um formato diferente, por isso, vamos passar como argumento do `format`o valor `%Y-%m-%d`, informando que as datas possuem primeiro o *ano* completo (ex.: 2020), *mês (ex.: 05), e dia (ex.: 12).

# %%
# df_reembolso["datEmissao"] = pd.to_datetime(df_reembolso.datEmissao, format="%Y-%m-%dT%H:%M:%S")
df_reembolso["datEmissao"].sample(50)
# Out:
# 241418   2019-06-30 00:00:00
# 150806   2019-04-24 00:00:00
# 54917    2019-06-10 00:00:00
# 118963   2019-11-12 00:00:00
# 284751   2019-09-30 00:00:00
# 34772    2019-12-09 00:00:00
# 16153    2019-10-02 00:00:00
# 213320   2019-11-20 23:00:00
# 7283     2019-02-06 00:00:00
# 159941   2019-11-21 23:00:00
# 138169   2019-11-19 23:00:00
# 115515   2019-07-11 00:00:00
# 280374   2019-12-12 00:00:00
# 138417   2019-05-28 00:00:00
# 95032    2019-01-13 00:00:00
# 278519   2019-02-04 00:00:00
# 114594                   NaT
# 126700   2019-03-17 00:00:00
# 211854   2019-06-26 12:00:00
# 107998   2019-08-29 00:00:00
# 65588    2019-10-01 00:00:00
# 9239     2019-01-29 00:00:00
# 248333   2019-10-09 00:00:00
# 182641   2019-09-25 00:00:00
# 263322   2019-02-18 00:00:00
# 183920   2019-03-14 00:00:00
# 275283   2019-11-12 00:00:00
# 120869   2019-02-20 00:00:00
# 261763   2019-04-08 00:00:00
# 39609    2019-05-08 00:00:00
# 268197   2019-05-20 00:00:00
# 262114   2019-02-21 00:00:00
# 135773   2019-02-15 00:00:00
# 198532   2019-12-03 00:00:00
# 27650    2019-02-15 00:00:00
# 94704                    NaT
# 6804     2019-11-11 23:00:00
# 177357   2019-08-01 00:00:00
# 278976   2019-10-29 00:00:00
# 164320   2019-02-08 00:00:00
# 2419     2019-06-28 00:00:00
# 27661    2019-06-27 00:00:00
# 172025   2019-06-10 00:00:00
# 228356   2019-04-02 00:00:00
# 122988   2019-03-18 00:00:00
# 270953   2019-04-30 00:00:00
# 126594   2019-08-04 00:00:00
# 62633    2019-05-17 00:00:00
# 199273   2019-02-14 00:00:00
# 237234   2019-08-14 00:00:00
# Name: datEmissao, dtype: datetime64[ns]

# %% [markdown]
# Caso essa conversão gere algum erro, você pode informar ao pandas como ele deve lidar com isso. O `to_datetime()` possue o argumento `errors`, que pode receber `ignore` caso você queria que os erros sejam ignorados, ou `coerce` caso você queria que os valores inválidos recebam `NaT`.

# %% [markdown]
# ##### Para quem quiser saber mais!
#
# Você deve estar se perguntando o porquê dessa conversão utilizando o `to_datetime`. _O que ganhamos com isso?_ Existem várias vantagens do Pandas entender que uma coluna é uma data. Uma dessas vantagens é que você vai poder trabalhar com os dados como uma série temporal, ou seja, um conjunto de registros ao longo do tempo.
#
# Os reembolsos se encaixam bem nisso... pense só, nossos dados são um conjunto de pedidos de reembolsos solicitados ao longo de um ano. Quando convertemos o dados para um datetime, podemos realizar algumas operações que só são possíveis com datas. Por exemplo, podemos selecionar uma janela de tempo:

# %%
df_reembolso.set_index("datEmissao").loc["2020-01-01":"2020-04-30"]
# Out:
#                   txNomeParlamentar           cpf ideCadastro  \
# datEmissao
# 2020-01-10  LIDERANÇA DO DEMOCRATAS           NaN        <NA>
# 2020-01-02     LIDERANÇA DO PODEMOS           NaN        <NA>
# 2020-01-04          LIDERANÇA DO PT           NaN        <NA>
# 2020-01-31          LIDERANÇA DO PT           NaN        <NA>
# 2020-01-07          LIDERANÇA DO PT           NaN        <NA>
# ...                             ...           ...         ...
# 2020-01-01              Enéias Reis  9.450581e+10      207309
# 2020-01-03           Fernando Borja  5.267385e+10      212504
# 2020-02-28           Fernando Borja  5.267385e+10      212504
# 2020-01-08              Dr. Gonçalo  5.461154e+09      212625
# 2020-01-31             Marcão Gomes  9.300886e+09      212749
#
#            nuCarteiraParlamentar nuLegislatura sgUF     sgPartido  \
# datEmissao
# 2020-01-10                   NaN          2019  NaN           NaN
# 2020-01-02                   NaN          2019  NaN           NaN
# 2020-01-04                   NaN          2019  NaN           NaN
# 2020-01-31                   NaN          2019  NaN           NaN
# 2020-01-07                   NaN          2019  NaN           NaN
# ...                          ...           ...  ...           ...
# 2020-01-01                   533          2019   MG         UNIÃO
# 2020-01-03                   547          2019   MG        AVANTE
# 2020-02-28                   547          2019   MG        AVANTE
# 2020-01-08                   548          2019   MA  REPUBLICANOS
# 2020-01-31                   551          2019   RJ            PL
#
#            codLegislatura numSubCota  \
# datEmissao
# 2020-01-10             56         12
# 2020-01-02             56          5
# 2020-01-04             56          1
# 2020-01-31             56          5
# 2020-01-07             56        120
# ...                   ...        ...
# 2020-01-01             56         10
# 2020-01-03             56          5
# 2020-02-28             56         10
# 2020-01-08             56          4
# 2020-01-31             56        120
#
#                                                  txtDescricao  \
# datEmissao
# 2020-01-10                          ASSINATURA DE PUBLICAÇÕES
# 2020-01-02               DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 2020-01-04  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2020-01-31               DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 2020-01-07      LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES
# ...                                                       ...
# 2020-01-01                                          TELEFONIA
# 2020-01-03               DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 2020-02-28                                          TELEFONIA
# 2020-01-08      CONSULTORIAS, PESQUISAS E TRABALHOS TÉCNICOS.
# 2020-01-31      LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES
#
#            numEspecificacaoSubCota txtDescricaoEspecificacao  \
# datEmissao
# 2020-01-10                       0                       NaN
# 2020-01-02                       0                       NaN
# 2020-01-04                       0                       NaN
# 2020-01-31                       0                       NaN
# 2020-01-07                       0                       NaN
# ...                            ...                       ...
# 2020-01-01                       0                       NaN
# 2020-01-03                       0                       NaN
# 2020-02-28                       0                       NaN
# 2020-01-08                       0                       NaN
# 2020-01-31                       0                       NaN
#
#                                       txtFornecedor          txtCNPJCPF  \
# datEmissao
# 2020-01-10            LINEAR COMUNICACAO LTDA - EPP  109.472.430/0019-5
# 2020-01-02            LINEAR COMUNICACAO LTDA - EPP  109.472.430/0019-5
# 2020-01-04   CONDE & DELL ARINGA - DES DE SOFTWARES  096.137.720/0017-3
# 2020-01-31    IVONEIDE FARIAS DE ARRUDA 58448292120  144.776.630/0010-6
# 2020-01-07                   PANTANAL VEÍCULOS LTDA  073.193.230/0019-1
# ...                                             ...                 ...
# 2020-01-01              TELEFÔNICA BRASIL S.A. VIVO  025.581.570/0016-2
# 2020-01-03  FACEBOOK SERVIÇOS ONLINE DO BRASIL LTDA  133.470.160/0011-7
# 2020-02-28                        CELULAR FUNCIONAL  000.000.000/0000-1
# 2020-01-08  INSTIT. MARANHENSE DE PESQ.PROT.AGROECO  150.703.730/0010-6
# 2020-01-31                CARRY SERVIÇOS E LOCAÇÕES  096.026.750/0018-5
#
#                   txtNumero indTipoDocumento  vlrDocumento vlrGlosa  \
# datEmissao
# 2020-01-10             2653                4       1400.00        0
# 2020-01-02             2646                4        540.00        0
# 2020-01-04             9649                0        200.00        0
# 2020-01-31              108                4       3400.00        0
# 2020-01-07             2932                4       2250.00        0
# ...                     ...              ...           ...      ...
# 2020-01-01  4407730/01/2020                0        429.44      9.5
# 2020-01-03         13903330                0        625.60        0
# 2020-02-28          7034860                0         41.44        0
# 2020-01-08               33                0      32400.00        0
# 2020-01-31             0035                0       1516.00        0
#
#             vlrLiquido numMes numAno numParcela txtPassageiro txtTrecho  \
# datEmissao
# 2020-01-10     1400.00     12   2019          0           NaN       NaN
# 2020-01-02      540.00     12   2019          0           NaN       NaN
# 2020-01-04      200.00     12   2019          0           NaN       NaN
# 2020-01-31     3400.00     12   2019          0           NaN       NaN
# 2020-01-07     2250.00     12   2019          0           NaN       NaN
# ...                ...    ...    ...        ...           ...       ...
# 2020-01-01      419.94     12   2019          0           NaN       NaN
# 2020-01-03      625.60     12   2019          0           NaN       NaN
# 2020-02-28       41.44     12   2019          0           NaN       NaN
# 2020-01-08    32400.00     12   2019          0           NaN       NaN
# 2020-01-31     1516.00     12   2019          0           NaN       NaN
#
#             numLote numRessarcimento datPagamentoRestituicao  vlrRestituicao  \
# datEmissao
# 2020-01-10  1667101              NaN                     NaN             NaN
# 2020-01-02  1669984              NaN                     NaN             NaN
# 2020-01-04  1667165              NaN                     NaN             NaN
# 2020-01-31  1670191              NaN                     NaN             NaN
# 2020-01-07  1667166              NaN                     NaN             NaN
# ...             ...              ...                     ...             ...
# 2020-01-01  1669485              NaN                     NaN             NaN
# 2020-01-03  1675071              NaN                     NaN             NaN
# 2020-02-28        0                0                     NaN             NaN
# 2020-01-08  1666704              NaN                     NaN             NaN
# 2020-01-31  1680650              NaN                     NaN             NaN
#
#            nuDeputadoId ideDocumento  \
# datEmissao
# 2020-01-10         2713      6994538
# 2020-01-02         3172      7000670
# 2020-01-04         2439      6994687
# 2020-01-31         2439      7001237
# 2020-01-07         2439      6994688
# ...                 ...          ...
# 2020-01-01         3446      6999178
# 2020-01-03         3462      7012146
# 2020-02-28         3462            0
# 2020-01-08         3463      6993447
# 2020-01-31         3465      7022622
#
#                                                  urlDocumento
# datEmissao
# 2020-01-10  https://www.camara.leg.br/cota-parlamentar/not...
# 2020-01-02  https://www.camara.leg.br/cota-parlamentar/not...
# 2020-01-04  https://www.camara.leg.br/cota-parlamentar/doc...
# 2020-01-31  https://www.camara.leg.br/cota-parlamentar/not...
# 2020-01-07  https://www.camara.leg.br/cota-parlamentar/not...
# ...                                                       ...
# 2020-01-01                                                NaN
# 2020-01-03  https://www.camara.leg.br/cota-parlamentar/doc...
# 2020-02-28                                                NaN
# 2020-01-08  https://www.camara.leg.br/cota-parlamentar/doc...
# 2020-01-31  https://www.camara.leg.br/cota-parlamentar/doc...
#
# [1898 rows x 31 columns]

# %% [markdown]
# Outras coisas são possíveis, como encontrar o dia da semana de cada uma dessas datas, calcular a média móvel, calcular quantos anos se passaram, ou agrupar os dados por janelas de tempo.

# %% [markdown]
# Também podemos verificar qual a data mais recente e mais antiga, por exemplo, executando:

# %%
df_reembolso.datEmissao.min()
# Out:
# Timestamp('2018-06-13 00:00:00')

# %% [markdown]
# #### 2. Remover caracteres diferentes de números da coluna `txtCNPJCPF`

# %% [markdown]
# A coluna `txtCNPJCPF` possuí inicialmente o seguinte padrão de valores:

# %%
df_reembolso["txtCNPJCPF"].head()
# Out:
# 0    037.139.030/0010-8
# 1    037.139.030/0010-8
# 2    037.139.030/0010-8
# 3    037.139.030/0010-8
# 4    037.139.030/0010-8
# Name: txtCNPJCPF, dtype: object

# %% [markdown]
# Iremos remover os caracteres diferentes de dígitos do conteúdo:

# %%
df_reembolso["txtCNPJCPF"] = df_reembolso["txtCNPJCPF"].str.replace(r"\D", "", regex=True)

# %%
df_reembolso["txtCNPJCPF"].head()
# Out:
# 0    03713903000108
# 1    03713903000108
# 2    03713903000108
# 3    03713903000108
# 4    03713903000108
# Name: txtCNPJCPF, dtype: object

# %% [markdown]
# #### 3. Refatorando a coluna de `indTipoDocumento`
#
# A coluna `indTipoDocumento` representa o tipo de documento do fiscal, podendo ser:
# - 0 (zero), para Nota Fiscal;
# - 1 (um), para Recibo;
# - 2 (dois), para Despesa no Exterior.

# %%
df_reembolso["indTipoDocumento"].sample(10)
# Out:
# 217428    0
# 282612    1
# 40165     1
# 85874     4
# 111745    0
# 180062    0
# 87870     1
# 50503     4
# 123876    0
# 179041    0
# Name: indTipoDocumento, dtype: object

# %%
df_reembolso.indTipoDocumento.unique()
# Out:
# array(['4', '0', '1', '3', '2'], dtype=object)

# %% [markdown]
# Ficará mais legível converter esses números para texto.
#
# Iremos fazer isso a seguir:

# %%
converters = {"0": "nota_fiscal", "1": "recibo", "2": "despesa_exterior", "4": None}

converters
# Out:
# {'0': 'nota_fiscal', '1': 'recibo', '2': 'despesa_exterior', '4': None}

# %%
df_reembolso.indTipoDocumento.replace(converters, inplace=True)

# %%
df_reembolso.indTipoDocumento.unique()
# Out:
# array([None, 'nota_fiscal', 'recibo', '3', 'despesa_exterior'],
#       dtype=object)

# %% [markdown]
# ## Aula 05: Analisando os dados da CEAP

# %%
df_reembolso = pd.read_csv("reembolso-2019/Ano-2019.csv", delimiter=";", low_memory=False)

# %% [markdown]
# ### Exemplo de perguntas iniciais

# %% [markdown]
# #### Quantos parlamentares solicitaram reembolso?
#
# Podemos contar a quantidade de registros únicos na coluna `txNomeParlamentar`.
#
# Mas é importante lembrar que em alguns casos o nome consta como `LIDERENÇA ...`.

# %%
txNomeParlamentar = df_reembolso.txNomeParlamentar.apply(lambda x: x.upper()).unique()
txNomeParlamentar
# Out:
# array(['LID.GOV-CD', 'LIDERANÇA DO AVANTE', 'LIDERANÇA DO CIDADANIA',
#        'LIDERANÇA DO DEMOCRATAS', 'LIDERANÇA DO NOVO',
#        'LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL',
#        'LIDERANÇA DO PDT', 'LIDERANÇA DO PODEMOS',
#        'LIDERANÇA DO PROGRESSISTAS', 'LIDERANÇA DO PSD',
#        'LIDERANÇA DO PSDB', 'LIDERANÇA DO PSOL', 'LIDERANÇA DO PT',
#        'LIDERANÇA DO PTB', 'LIDERANÇA DO SOLIDARIEDADE', 'LIDMIN',
#        'SILVIO COSTA', 'IZALCI LUCAS', 'DANILO FORTE', 'MARIA HELENA',
#        'NORMA AYUB', 'FAUSTO PINATO', 'IRACEMA PORTELLA', 'JÚLIA MARINHO',
#        'FÁBIO HENRIQUE', 'BACELAR', 'FELIPE CARRERAS', 'CELSO PANSERA',
#        'SIMÃO SESSIM', 'ARLINDO CHINAGLIA', 'ARNALDO FARIA DE SÁ',
#        'BETO MANSUR', 'CELSO RUSSOMANNO', 'ALEX CANZIANI',
#        'GUSTAVO FRUET', 'OSMAR SERRAGLIO', 'RUBENS BUENO',
#        'HENRIQUE FONTANA', 'LUIS CARLOS HEINZE', 'POMPEO DE MATTOS',
#        'IVAN VALENTE', 'JORGE TADEU MUDALEN', 'NELSON MARQUEZELLI',
#        'SILVIO TORRES', 'CELSO JACOB', 'ALBERTO FRAGA',
#        'ANTONIO CARLOS MENDES THAME', 'JÚLIO DELGADO', 'RUI FALCÃO',
#        'AUGUSTO CARVALHO', 'JOVAIR ARANTES', 'ROBERTO BALESTRA',
#        'OSMAR TERRA', 'ANGELA AMIN', 'BENEDITA DA SILVA', 'JOSÉ REINALDO',
#        'CESAR SOUZA', 'DILCEU SPERAFICO', 'HERMES PARCIANELLO',
#        'LUIZ CARLOS HAULY', 'NELSON MEURER', 'RICARDO BARROS',
#        'RENILDO CALHEIROS', 'SÉRGIO BRITO', 'DARCÍSIO PERONDI',
#        'JANETE CAPIBERIBE', 'WLADIMIR COSTA', 'ZÉ GERALDO',
#        'PERPÉTUA ALMEIDA', 'YEDA CRUSIUS', 'VALDIR COLATTO',
#        'PAULO FEIJÓ', 'BENJAMIN MARANHÃO', 'LUIZ COUTO',
#        'WELLINGTON ROBERTO', 'WILSON SANTIAGO',
#        'MAURÍCIO QUINTELLA LESSA', 'BOSCO COSTA', 'ALICE PORTUGAL',
#        'DANIEL ALMEIDA', 'ELCIONE BARBALHO', 'GIOVANNI QUEIROZ',
#        'JOSÉ PRIANTE', 'ÁTILA LINS', 'PAUDERNEY AVELINO',
#        'JOSÉ CARLOS ARAÚJO', 'JOSIAS GOMES', 'LEONARDO MONTEIRO',
#        'MÁRIO HERINGER', 'ODAIR CUNHA', 'PATRUS ANANIAS',
#        'REGINALDO LOPES', 'CARLOS MANATO', 'CHICO ALENCAR', 'DELEY',
#        'MARINHA RAUPP', 'FREIRE JÚNIOR', 'GASTÃO VIEIRA', 'SARNEY FILHO',
#        'ANÍBAL GOMES', 'ANTONIO BALHMANN', 'RAIMUNDO GOMES DE MATOS',
#        'MARCUS VICENTE', 'JULIO LOPES', 'LEONARDO PICCIANI',
#        'CARLOS SAMPAIO', 'GILBERTO NASCIMENTO', 'JEFFERSON CAMPOS',
#        'JOSÉ MENTOR', 'LOBBE NETO', 'VICENTINHO', 'LEÔNIDAS CRISTINO',
#        'ROBERTO PESSOA', 'VICENTE ARRUDA', 'JÚLIO CESAR', 'PAES LANDIM',
#        'JOSUÉ BENGTSON', 'NILSON PINTO', 'SILAS CÂMARA',
#        'NILTON CAPIXABA', 'JOÃO CAMPOS', 'RUBENS OTONI', 'SANDES JÚNIOR',
#        'GERALDO RESENDE', 'VANDER LOUBET', 'ASSIS DO COUTO', 'GIACOBO',
#        'TAKAYAMA', 'JORGE BOEIRA', 'JOSÉ OTÁVIO GERMANO',
#        'MARIA DO ROSÁRIO', 'ONYX LORENZONI', 'PAULO PIMENTA',
#        'GONZAGA PATRIOTA', 'MENDONÇA FILHO', 'WOLNEY QUEIROZ',
#        'PEDRO FERNANDES', 'ÁTILA LIRA', 'MARCELO CASTRO',
#        'DAMIÃO FELICIANO', 'MARCONDES GADELHA', 'ANDRÉ DE PAULA',
#        'LUCIANO BIVAR', 'BENITO GAMA', 'CLAUDIO CAJADO',
#        'JOSÉ CARLOS ALELUIA', 'JOSÉ ROCHA', 'GIVALDO CARIMBÃO',
#        'JUTAHY JUNIOR', 'NELSON PELLEGRINO', 'PAULO MAGALHÃES',
#        'LINCOLN PORTELA', 'AÉCIO NEVES', 'BONIFÁCIO DE ANDRADA',
#        'CARLOS MELLES', 'EDUARDO BARBOSA', 'JAIME MARTINS', 'LUIZ SÉRGIO',
#        'RODRIGO MAIA', 'MAURO LOPES', 'SARAIVA FELIPE', 'LUIZA ERUNDINA',
#        'MILTON MONTI', 'PEDRO CHAVES', 'AROLDE DE OLIVEIRA',
#        'JANDIRA FEGHALI', 'LAURA CARNEIRO', 'MIRO TEIXEIRA',
#        'MAURÍCIO DZIEDRICKI', 'MARCELO MATOS', 'MARCELO FREIXO',
#        'MÁRCIO JERRY', 'DRA. SORAYA MANATO', 'LUANA COSTA',
#        'PEDRO AUGUSTO BEZERRA', 'SANTINI', 'LEUR LOMANTO JÚNIOR',
#        'EDUARDO BOLSONARO', 'FERNANDO MONTEIRO', 'STEFANO AGUIAR',
#        'CACÁ LEÃO', 'CRISTIANE BRASIL', 'LUCIO VIEIRA LIMA',
#        'HERÁCLITO FORTES', 'LAFAYETTE DE ANDRADA', 'ERIVELTON SANTANA',
#        'CABUÇU BORGES', 'GLEISI HOFFMANN', 'JAQUELINE CASSOL',
#        'BENES LEOCÁDIO', 'JOÃO MARCELO SOUZA', 'VALMIR PRASCIDELLI',
#        'JOSI NUNES', 'GELSON AZEVEDO', 'DARCI DE MATOS',
#        'MARCELO SQUASSONI', 'ADRIANO DO BALDY', 'PEDRO PAULO',
#        'RONALDO MARTINS', 'PEDRO LUCAS FERNANDES', 'GABRIEL GUIMARÃES',
#        'GORETE PEREIRA', 'JARBAS VASCONCELOS', 'ENIO VERRI', 'MARCO MAIA',
#        'ANDRÉ FIGUEIREDO', 'MARCELO MORAES', 'PAULO RAMOS',
#        'EDMILSON RODRIGUES', 'CRISTIANO VALE', 'AFONSO HAMM',
#        'VICENTINHO JÚNIOR', 'LÍDICE DA MATA', 'BETO FARO',
#        'AELTON FREITAS', 'ANTONIO BULHÕES', 'VALADARES FILHO',
#        'INDIO DA COSTA', 'ARNALDO JARDIM', 'BRUNO ARAÚJO',
#        'CARLOS ZARATTINI', 'CARLOS BEZERRA', 'CELSO MALDANER',
#        'CLEBER VERDE', 'DAGOBERTO NOGUEIRA', 'DÉCIO LIMA', 'EDIO LOPES',
#        'EDUARDO DA FONTE', 'EFRAIM FILHO', 'FÁBIO RAMALHO', 'FÁBIO FARIA',
#        'FELIPE MAIA', 'FELIPE BORNIER', 'FERNANDO COELHO FILHO',
#        'FLAVIANO MELO', "CHICO D'ANGELO", 'CHICO LOPES', 'GEORGE HILTON',
#        'PEPE VARGAS', 'HUGO LEAL', 'ALFREDO KAEFER',
#        'JOÃO CARLOS BACELAR', 'JOÃO MAIA', 'JOSÉ AIRTON FÉLIX CIRILO',
#        'JOSÉ GUIMARÃES', 'RICARDO TRIPOLI', 'JULIÃO AMIN', 'LAERTE BESSA',
#        'LÁZARO BOTELHO', 'LEONARDO QUINTÃO', 'LINDOMAR GARÇON',
#        'LUIZ FERNANDO FARIA', 'PAULO TEIXEIRA', 'MARCOS MONTES',
#        'JÔ MORAES', 'MAURO MARIANI', 'MAURO NAZIF', 'MIGUEL CORRÊA',
#        'BILAC PINTO', 'OTAVIO LEITE', 'PAULO ABI-ACKEL',
#        'PAULINHO DA FORÇA', 'RAUL HENRY', 'RENATO MOLLING',
#        'ROBERTO BRITTO', 'RODRIGO DE CASTRO', 'ROGÉRIO MARINHO',
#        'SÉRGIO MORAES', 'VALTENIR PEREIRA', 'VANDERLEI MACRIS',
#        'VINICIUS CARVALHO', 'WALDIR MARANHÃO', 'WALTER IHOSHI',
#        'LELO COIMBRA', 'TIAGO DIMAS', 'DOMINGOS NETO', 'DANIEL VILELA',
#        'NERI GELLER', 'MARCELO ARO', 'PROFESSOR VICTÓRIO GALLI',
#        'MÁRCIO MARINHO', 'LAERCIO OLIVEIRA', 'GLAUBER BRAGA',
#        'ROBERTO ALVES', 'MILTON VIEIRA', 'MARCEL VAN HATTEM',
#        'TÚLIO GADÊLHA', 'ASSIS CARVALHO', 'MARCUS PESTANA',
#        'ROGÉRIO ROSSO', 'AFONSO FLORENCE', 'JORGINHO MELLO', 'LUIS TIBÉ',
#        'ALESSANDRO MOLON', 'AUREO RIBEIRO', 'RONALDO BENEDET',
#        'PAULO FOLETTO', 'WELITON PRADO', 'AGUINALDO RIBEIRO',
#        'DANILO CABRAL', 'ANTONIO IMBASSAHY', 'JHONATAN DE JESUS',
#        'ELI CORRÊA FILHO', 'LAURIETE', 'MARCON', 'MARCO TEBALDI',
#        'BOHN GASS', 'ARTHUR LIRA', 'ANDRE MOURA', 'JUNJI ABE',
#        'ALEXANDRE LEITE', 'DANRLEI DE DEUS HINTERHOLZ', 'ANTONIO BRITO',
#        'PADRE JOÃO', 'PAULO FREIRE COSTA', 'ALCEU MOREIRA',
#        'MISSIONÁRIO JOSÉ OLIMPIO', 'MARA GABRILLI', 'WALDENOR PEREIRA',
#        'JERÔNIMO GOERGEN', 'JOÃO RODRIGUES', 'JORGE CÔRTE REAL',
#        'JOÃO ARRUDA', 'ERIKA KOKAY', 'CÉSAR HALUM', 'EDMAR ARRUDA',
#        'ALBERTO FILHO', 'FÁBIO TRAD', 'DIEGO ANDRADE', 'BRUNA FURLAN',
#        'VINICIUS GURGEL', 'ZECA DIRCEU', 'HEULER CRUVINEL',
#        'FLÁVIA MORAIS', 'DIMAS FABIANO', 'ARTHUR OLIVEIRA MAIA',
#        'PR. MARCO FELICIANO', 'ARNALDO JORDY', 'PEDRO UCZAI',
#        'JOSE STÉDILE', 'VALMIR ASSUNÇÃO', 'TONINHO PINHEIRO',
#        'SERGIO ZVEITER', 'SIBÁ MACHADO', 'THIAGO PEIXOTO', 'JOSÉ NUNES',
#        'SANDRO ALEX', 'VICENTE CANDIDO', 'LUCIANA SANTOS',
#        'SÁGUAS MORAES', 'WALNEY ROCHA', 'ZÉ SILVA', 'MANDETTA',
#        'RUY CARNEIRO', 'WILSON FILHO', 'RONALDO FONSECA',
#        'PROFESSORA DORINHA SEABRA REZENDE', 'EROS BIONDINI',
#        'PROFESSORA MARCIVANIA', 'PASTOR EURICO', 'DR. JORGE SILVA',
#        'LUIZ CARLOS', 'DELEGADO FRANCISCHINI', 'ESPERIDIÃO AMIN',
#        'ROGÉRIO PENINHA MENDONÇA', 'ROBERTO DE LUCENA', 'RENZO BRAZ',
#        'RICARDO IZAR', 'KEIKO OTA', 'MARCELO AGUIAR', 'LEOPOLDO MEYER',
#        'AUGUSTO COUTINHO', 'FÉLIX MENDONÇA JÚNIOR', 'GUILHERME MUSSI',
#        'GENECIAS NORONHA', 'JEAN WYLLYS', 'GIOVANI CHERINI', 'HUGO MOTTA',
#        'FERNANDO TORRES', 'FRANCISCO FLORIANO', 'DOMINGOS SÁVIO',
#        'TIRIRICA', 'EMIDINHO MADEIRA', 'LUIZ NISHIMORI',
#        'RONALDO NOGUEIRA', 'DELEGADO WALDIR', 'CARMEN ZANOTTO',
#        'NILSON LEITÃO', 'MAGDA MOFATTO', 'WEVERTON ROCHA',
#        'MARCOS ROGÉRIO', 'SIMPLÍCIO ARAÚJO', 'PAULÃO',
#        'MARGARIDA SALOMÃO', 'RENATO ANDRADE', 'FABIO REIS',
#        'SUBTENENTE GONZAGA', 'LUIZ CARLOS RAMOS', 'LEO DE BRITO',
#        'MAJOR OLIMPIO', 'EVANDRO GUSSI', 'CAPITÃO AUGUSTO',
#        'DR. SINVAL MALHEIROS', 'ANDRÉ ABDON', 'LEANDRE',
#        'ALEXANDRE SERFIOTIS', 'BEBETO', 'AFONSO MOTTA', 'ALAN RICK',
#        'ANGELIM', 'CÉSAR MESSIAS', 'JÉSSICA SALES', 'ROCHA',
#        'CÍCERO ALMEIDA', 'JHC', 'MARX BELTRÃO', 'PEDRO VILELA',
#        'RONALDO LESSA', 'ALFREDO NASCIMENTO', 'CONCEIÇÃO SAMPAIO',
#        'HISSA ABRAHÃO', 'JOZI ARAÚJO', 'MARCOS REATEGUI', 'CAETANO',
#        'ELMAR NASCIMENTO', 'IRMÃO LAZARO', 'JOÃO GUALBERTO',
#        'JORGE SOLLA', 'MÁRIO NEGROMONTE JR.', 'PAULO AZI',
#        'RONALDO CARLETTO', 'TIA ERON', 'ULDURICO JUNIOR',
#        'ADAIL CARNEIRO', 'CABO SABINO', 'LUIZIANNE LINS', 'MACEDO',
#        'ODORICO MONTEIRO', 'VITOR VALIM', 'RÔNEY NEMER',
#        'EVAIR VIEIRA DE MELO', 'GIVALDO VIEIRA', 'HELDER SALOMÃO',
#        'SERGIO VIDIGAL', 'CÉLIO SILVEIRA', 'FÁBIO SOUSA',
#        'GIUSEPPE VECCI', 'LUCAS VERGILIO', 'MARCOS ABRÃO',
#        'ALUISIO MENDES', 'ANDRÉ FUFUCA', 'ELIZIANE GAMA', 'HILDO ROCHA',
#        'JUNIOR MARRECA', 'JUSCELINO FILHO', 'RUBENS PEREIRA JÚNIOR',
#        'VICTOR MENDES', 'ZÉ CARLOS', 'ADELMO CARNEIRO LEÃO',
#        'CAIO NARCIO', 'DÂMINA PEREIRA', 'DELEGADO EDSON MOREIRA',
#        'LAUDIVIO CARVALHO', 'MISAEL VARELLA', 'NEWTON CARDOSO JR',
#        'RODRIGO PACHECO', 'TENENTE LÚCIO', 'TEREZA CRISTINA',
#        'ZECA DO PT', 'ADILTON SACHETTI', 'EZEQUIEL FONSECA',
#        'FABIO GARCIA', 'BETO SALAME', 'FRANCISCO CHAPADINHA',
#        'DELEGADO ÉDER MAURO', 'HÉLIO LEITE', 'JOAQUIM PASSARINHO',
#        'SIMONE MORGADO', 'PEDRO CUNHA LIMA', 'VENEZIANO VITAL DO RÊGO',
#        'ADALBERTO CAVALCANTI', 'BETINHO GOMES', 'DANIEL COELHO',
#        'JOÃO FERNANDO COUTINHO', 'KAIO MANIÇOBA', 'MARINALDO ROSENDO',
#        'RICARDO TEOBALDO', 'SEBASTIÃO OLIVEIRA', 'TADEU ALENCAR',
#        'ZECA CAVALCANTI', 'CAPITÃO FÁBIO ABREU', 'REJANE DIAS',
#        'RODRIGO MARTINS', 'ALIEL MACHADO', 'CHRISTIANE DE SOUZA YARED',
#        'DIEGO GARCIA', 'ROMAN', 'LUCIANO DUCCI', 'SERGIO SOUZA',
#        'TONINHO WANDSCHEER', 'ROSSONI', 'ALEXANDRE VALLE',
#        'ALTINEU CÔRTES', 'CABO DACIOLO', 'CLARISSA GAROTINHO',
#        'EZEQUIEL TEIXEIRA', 'MARCO ANTÔNIO CABRAL', 'MARCOS SOARES',
#        'ROBERTO SALES', 'ROSANGELA GOMES', 'SORAYA SANTOS',
#        'SÓSTENES CAVALCANTE', 'BETO ROSADO', 'ZENAIDE MAIA',
#        'ANTÔNIO JÁCOME', 'RAFAEL MOTTA', 'WALTER ALVES', 'EXPEDITO NETTO',
#        'LUCIO MOSQUINI', 'LUIZ CLÁUDIO', 'MARIANA CARVALHO',
#        'ABEL MESQUITA JR.', 'CARLOS ANDRADE', 'HIRAN GONÇALVES',
#        'REMÍDIO MONAI', 'SHÉRIDAN', 'CARLOS GOMES', 'COVATTI FILHO',
#        'HEITOR SCHUCH', 'JOÃO DERLY', 'GEOVANIA DE SÁ',
#        'JOÃO PAULO KLEINÜBING', 'ADELSON BARRETO', 'FÁBIO MITIDIERI',
#        'JOÃO DANIEL', 'JONY MARCOS', 'ALEX MANENTE', 'ANA PERUGINI',
#        'ANDRES SANCHEZ', 'BALEIA ROSSI', 'EDUARDO CURY', 'FLAVINHO',
#        'FLORIANO PESARO', 'GOULART', 'HERCULANO PASSOS',
#        'LUIZ LAURO FILHO', 'MARCIO ALVINO', 'MIGUEL HADDAD',
#        'MIGUEL LOMBARDI', 'NILTO TATTO', 'ORLANDO SILVA',
#        'JOÃO PAULO PAPA', 'RENATA ABREU', 'SAMUEL MOREIRA', 'SÉRGIO REIS',
#        'VITOR LIPPI', 'CARLOS HENRIQUE GAGUIM', 'DULCE MIRANDA',
#        'ROBERTO GÓES', 'GIOVANI FELTES', 'MOSES RODRIGUES',
#        'RAQUEL MUNIZ', 'BRUNNY', 'MARCELO ÁLVARO ANTÔNIO',
#        'MÁRCIO BIOLCHI', 'MAJOR VITOR HUGO', 'OSMAR BERTOLDI',
#        'ELIZEU DIONIZIO', 'MERLONG SOLANO', 'WADIH DAMOUS',
#        'FLÁVIO NOGUEIRA', 'ZÉ AUGUSTO NALIN', 'WILSON BESERRA',
#        'PAULO EDUARDO MARTINS', 'NIVALDO ALBUQUERQUE', 'CAJAR NARDES',
#        'ANDRÉ AMARAL', 'MARCELO DELAROLI', 'VAIDON OLIVEIRA',
#        'LOURIVAL GOMES', 'TITO', 'GREYCE ELIAS', 'EMANUEL PINHEIRO NETO',
#        'PROF. GEDEÃO AMORIM', 'JUNIOR CORINGA', 'DR. LUIZ OVANDO',
#        'CAMILO CAPIBERIBE', 'ALINE GURGEL', 'FLÁVIA ARRUDA', 'DA VITORIA',
#        'AMARO NETO', 'ROSE MODESTO', 'BETO PEREIRA', 'LÉO MORAES',
#        'SILVIA CRISTINA', 'CARLOS CHIODINI', 'RICARDO GUIDI',
#        'OSIRES DAMASO', 'ELI BORGES', 'GILSON MARQUES', 'RODRIGO COELHO',
#        'DANIEL FREITAS', 'FABIO SCHIOCHET', 'CAROLINE DE TONI',
#        'CÉLIO MOURA', 'FELIPE RIGONI', 'JULIO CESAR RIBEIRO',
#        'HÉLIO COSTA', 'BIA KICIS', 'LEDA SADALA', 'CORONEL ARMANDO',
#        'CORONEL CHRISÓSTOMO', 'ACÁCIO FAVACHO', 'CELINA LEÃO',
#        'LUIS MIRANDA', 'LOESTER TRUTIS', 'PROFESSOR ISRAEL BATISTA',
#        'VALDEVAN NOVENTA', 'JOSE MARIO SCHREINER', 'SARGENTO FAHUR',
#        'BIBO NUNES', 'ELIAS VAZ', 'PROFESSOR ALCIDES', 'JOSÉ NELTO',
#        'FRANCISCO JR.', 'FREI ANASTACIO RIBEIRO', 'GERVÁSIO MAIA',
#        'PEDRO LUPION', 'VERMELHO', 'BOCA ABERTA', 'FELIPE FRANCISCHINI',
#        'SCHIAVINATO', 'ALINE SLEUTJES', 'MARLON SANTOS', 'LUCAS REDECKER',
#        'LIZIANE BAYER', 'PEDRO WESTPHALEN', 'FERNANDA MELCHIONNA',
#        'GUSTINHO RIBEIRO', 'DANIEL TRZECIAK', 'LUISA CANZIANI',
#        'FILIPE BARROS', 'DR. ZACHARIAS CALIL', 'ALCIDES RODRIGUES',
#        'AROLDO MARTINS', 'NEREU CRISPIM', 'SANDERSON', 'LUIZÃO GOULART',
#        'GLAUSTIN DA FOKUS', 'JULIAN LEMOS', 'EDNA HENRIQUE',
#        'OSSESIO SILVA', 'ANDRÉ FERREIRA', 'SILVIO COSTA FILHO',
#        'CARLOS VERAS', 'FERNANDO RODOLFO', 'MARÍLIA ARRAES',
#        'JOÃO H. CAMPOS', 'MARGARETE COELHO', 'MARCOS AURÉLIO SAMPAIO',
#        'MARINA SANTOS', 'MARCELO CALERO', 'DRA. VANDA MILANI',
#        'JESUS SÉRGIO', 'ISNALDO BULHÕES JR.', 'SEVERINO PESSOA',
#        'SERGIO TOLEDO', 'DR. LEONARDO', 'CHRISTINO AUREO',
#        'OTONI DE PAULA', 'GURGEL', 'HELIO LOPES', 'PROFESSOR JOZIEL',
#        'FLORDELIS', 'LUIZ ANTONIO CORRÊA', 'NELSON BARBUDO',
#        'DOUTOR LUIZINHO', 'DELEGADO ANTÔNIO FURTADO', 'MÁRCIO LABRE',
#        'NATÁLIA BONAVIDES', 'DANIEL SILVEIRA', 'LUIZ LIMA',
#        'GUTEMBERG REIS', 'JUNINHO DO PNEU', 'MAJOR FABIANA',
#        'DANIELA DO WAGUINHO', 'CARLOS JORDY', 'PAULO GANIME',
#        'CHRIS TONIETTO', 'WLADIMIR GAROTINHO', 'TALÍRIA PETRONE',
#        'HAROLDO CATHEDRAL', 'TEREZA NELMA', 'PROFESSORA ROSA NEIDE',
#        'JOENIA WAPICHANA', 'MANUEL MARCOS', 'MARA ROCHA', 'JOSÉ MEDEIROS',
#        'GENERAL GIRÃO', 'JUAREZ COSTA', 'OTTACI NASCIMENTO',
#        'CHIQUINHO BRAZÃO', 'FELÍCIO LATERÇA', 'VINICIUS FARAH',
#        'NICOLETTI', 'ROGÉRIO CORREIA', 'DR. JAZIEL', 'EUCLYDES PETTERSEN',
#        'VILSON DA FETAEMG', 'GENERAL PETERNELLI', 'LUIZ CARLOS MOTTA',
#        'MAURO BENEVIDES FILHO', 'CAPITÃO WAGNER', 'CÉLIO STUDART',
#        'ROBÉRIO MONTEIRO', 'CHARLLES EVANGELISTA', 'GILBERTO ABRAMO',
#        'PAULO GUEDES', 'FRED COSTA', 'AIRTON FALEIRO', 'CELSO SABINO',
#        'JÚNIOR FERRARI', 'OLIVAL MARQUES', 'CÁSSIO ANDRADE',
#        'EDUARDO COSTA', 'ALENCAR SANTANA', 'BOZZELLA',
#        'ALEXANDRE PADILHA', 'CEZINHA DE MADUREIRA', 'VAVÁ MARTINS',
#        'MARCOS PEREIRA', 'CARLA ZAMBELLI', 'IGOR TIMO', 'ÁUREA CAROLINA',
#        'FRANCO CARTAFINA', 'DAVID SOARES', 'DELEGADO MARCELO FREITAS',
#        'GUIGA PEIXOTO', 'CORONEL TADEU', 'ANDRÉ JANONES',
#        'ALEXIS FONTEYNE', 'ZÉ VITOR', 'DR. FREDERICO', 'TIAGO MITRAUD',
#        'JUNIO AMARAL', 'ABOU ANNI', 'MARCO BERTAIOLLI', 'LUCAS GONZALEZ',
#        'PINHEIRINHO', 'ROSANA VALLE',
#        'LUIZ PHILIPPE DE ORLEANS E BRAGANÇA', 'GENINHO ZULIANI',
#        'ADRIANA VENTURA', 'POLICIAL KATIA SASTRE', 'RODRIGO AGOSTINHO',
#        'GUILHERME DERRITE', 'VINICIUS POIT', 'IDILVAN ALENCAR',
#        'TABATA AMARAL', 'SÂMIA BOMFIM', 'KIM KATAGUIRI', 'ENRICO MISASI',
#        'PAULO BENGTSON', 'MARIA ROSAS', 'EDUARDO BISMARCK',
#        'DENIS BEZERRA', 'LUIZ FLÁVIO GOMES', 'ALEXANDRE FROTA',
#        'ALÊ SILVA', 'JOICE HASSELMANN', 'LÉO MOTTA', 'HEITOR FREIRE',
#        'AJ ALBUQUERQUE', 'JÚNIOR MANO', 'BOSCO SARAIVA', 'EDUARDO BRAIDE',
#        'PASTOR SARGENTO ISIDÓRIO', 'ABÍLIO SANTANA', 'JOSÉ RICARDO',
#        'MARCELO RAMOS', 'SIDNEY LEITE', 'MARCELO NILO', 'ZÉ NETO',
#        'ADOLFO VIANA', 'BIRA DO PINDARÉ', 'EDILÁZIO JÚNIOR',
#        'JOSIMAR MARANHÃOZINHO', 'IGOR KANNÁRIO',
#        'PROFESSORA DAYANE PIMENTEL', 'MARRECA FILHO', 'RAIMUNDO COSTA',
#        'DELEGADO PABLO', 'PASTOR GIL', 'ALEX SANTANA',
#        'CAPITÃO ALBERTO NETO', 'OTTO ALENCAR FILHO', 'JUNIOR LOURENÇO',
#        'GIL CUTRIM', 'JOÃO ROMA', 'WASHINGTON CORAÇÃO VALENTE',
#        'FELIPE SOUZA', 'MARFIZA GALVÃO', 'GUSTAVO MITRE',
#        'CORONEL BITTENCOURT', 'CARLA STEPHANINI', 'CHARLES FERNANDES',
#        'PATRICIA FERRAZ', 'DAVID MIRANDA', 'JORGE BRAZ', 'MARCELO BRUM',
#        'REINHOLD STEPHANES', 'TED CONTI', 'BIA CAVASSA', 'ENÉIAS REIS',
#        'JOSEILDO RAMOS', 'RICARDO PERICAR', 'FABIANO TOLENTINO',
#        'FERNANDO BORJA', 'DR. GONÇALO', 'MARCÃO GOMES'], dtype=object)

# %%
len(txNomeParlamentar)
# Out:
# 820

# %% [markdown]
# #### Quais os 10 parlamentares mais citados?
#
# Para responder essa pergunta, precisamos verificar a frequência em que os nomes dos parlamentares aparecem no dataset.

# %%
df_reembolso.txNomeParlamentar.value_counts().sort_values(ascending=False).to_frame().head(10)
# Out:
#                           count
# txNomeParlamentar
# Diego Garcia               1735
# Zeca Dirceu                1631
# Maria do Rosário           1540
# Glauber Braga              1489
# Jorge Solla                1425
# Guiga Peixoto              1351
# Dimas Fabiano              1330
# Henrique Fontana           1325
# Vitor Lippi                1308
# Delegado Antônio Furtado   1269

# %% [markdown]
# #### Quais os gastos mais frequentes?
#
# Podemos aplicar o `values_counts` na coluna `txtDescricao`, para identificar a frequência dos tipos de gastos.

# %%
df_reembolso.txtDescricao.value_counts()  # normalize=True
# Out:
# txtDescricao
# PASSAGEM AÉREA - RPA                                         81582
# COMBUSTÍVEIS E LUBRIFICANTES.                                64765
# SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO                    31558
# MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE PARLAMENTAR    22019
# TELEFONIA                                                    21880
# FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                   17765
# SERVIÇOS POSTAIS                                             14961
# DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                         10946
# LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES                 6279
# HOSPEDAGEM ,EXCETO DO PARLAMENTAR NO DISTRITO FEDERAL.        5579
# PASSAGEM AÉREA - SIGEPA                                       4073
# PASSAGEM AÉREA - REEMBOLSO                                    3148
# CONSULTORIAS, PESQUISAS E TRABALHOS TÉCNICOS.                 2397
# PASSAGENS TERRESTRES, MARÍTIMAS OU FLUVIAIS                   1136
# ASSINATURA DE PUBLICAÇÕES                                      605
# SERVIÇO DE SEGURANÇA PRESTADO POR EMPRESA ESPECIALIZADA.       563
# LOCAÇÃO OU FRETAMENTO DE AERONAVES                             126
# PARTICIPAÇÃO EM CURSO, PALESTRA OU EVENTO SIMILAR               41
# LOCAÇÃO OU FRETAMENTO DE EMBARCAÇÕES                            30
# Name: count, dtype: int64

# %% [markdown]
# #### Qual o maior gasto com alimentação foi registrado?
#
# Filtrando por tipo de descrição e acessando o valor máximo, podemos saber isso.

# %%
df_reembolso[df_reembolso.txtDescricao == "FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR"][
    "vlrLiquido"
].max()
# Out:
# 8000.0

# %% [markdown]
# #### Qual ou quais parlamentares foram responsáveis por solicitar esse reembolso com gasto de alimentação?
#
# Para saber isso, vamos precisar pegar o valor máximo registrado na categoria `FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR`, depois vamos precisar filtrar apenas por registros presentes nessa categoria. Porque assim, evitamos pegar registros com o mesmo valor mas que estão relacionados com outras categorias.

# %%
gasto_alimentacao = df_reembolso.txtDescricao == "FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR"

alimentacao_max = df_reembolso[
    df_reembolso.txtDescricao == "FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR"
]["vlrLiquido"].max()

df_reembolso[gasto_alimentacao & (df_reembolso.vlrLiquido == alimentacao_max)]
# Out:
#               txNomeParlamentar  cpf ideCadastro nuCarteiraParlamentar  \
# 264  LIDERANÇA DO PROGRESSISTAS  NaN        <NA>                   NaN
# 265  LIDERANÇA DO PROGRESSISTAS  NaN        <NA>                   NaN
# 266  LIDERANÇA DO PROGRESSISTAS  NaN        <NA>                   NaN
#
#     nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 264          2019  NaN       NaN             56         13
# 265          2019  NaN       NaN             56         13
# 266          2019  NaN       NaN             56         13
#
#                                    txtDescricao numEspecificacaoSubCota  \
# 264  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 265  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 266  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
#
#     txtDescricaoEspecificacao                       txtFornecedor  \
# 264                       NaN  RONILDA FRANCISCA RIBEIRO DOS REIS
# 265                       NaN  RONILDA FRANCISCA RIBEIRO DOS REIS
# 266                       NaN  RONILDA FRANCISCA RIBEIRO DOS REIS
#
#          txtCNPJCPF  txtNumero indTipoDocumento          datEmissao  \
# 264  20869131000117  001525287      nota_fiscal 2019-11-07 23:00:00
# 265  20869131000117  001546052      nota_fiscal 2019-11-24 23:00:00
# 266  20869131000117  001579281      nota_fiscal 2019-12-15 23:00:00
#
#      vlrDocumento vlrGlosa  vlrLiquido numMes numAno numParcela txtPassageiro  \
# 264        8000.0        0      8000.0     10   2019          0           NaN
# 265        8000.0        0      8000.0     11   2019          0           NaN
# 266        8000.0        0      8000.0     12   2019          0           NaN
#
#     txtTrecho  numLote numRessarcimento datPagamentoRestituicao  \
# 264       NaN  1651228              NaN                     NaN
# 265       NaN  1655704              NaN                     NaN
# 266       NaN  1663508              NaN                     NaN
#
#      vlrRestituicao nuDeputadoId ideDocumento  \
# 264             NaN         3461      6959055
# 265             NaN         3461      6969841
# 266             NaN         3461      6987099
#
#                                           urlDocumento
# 264  https://www.camara.leg.br/cota-parlamentar/doc...
# 265  https://www.camara.leg.br/cota-parlamentar/doc...
# 266  https://www.camara.leg.br/cota-parlamentar/doc...

# %% [markdown]
# #### Qual o parlamentar com o maior valor de reembolso?
#
# Uma forma de saber isso, é comparando o valor da nota de reembolso com o valor máximo presente na base.

# %%
df_reembolso[df_reembolso.vlrLiquido == df_reembolso.vlrLiquido.max()]
# Out:
#       txNomeParlamentar           cpf ideCadastro nuCarteiraParlamentar  \
# 88770     Weliton Prado  8.471985e+10      160518                   270
#
#       nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 88770          2019   MG      PROS             56          5
#
#                                txtDescricao numEspecificacaoSubCota  \
# 88770  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       0
#
#       txtDescricaoEspecificacao                    txtFornecedor  \
# 88770                       NaN  Athalaia Grafica e Editora Ltda
#
#            txtCNPJCPF txtNumero indTipoDocumento datEmissao  vlrDocumento  \
# 88770  02717866000143     12497      nota_fiscal 2019-12-20      145140.0
#
#       vlrGlosa  vlrLiquido numMes numAno numParcela txtPassageiro txtTrecho  \
# 88770        0    145140.0     12   2019          0           NaN       NaN
#
#        numLote numRessarcimento datPagamentoRestituicao  vlrRestituicao  \
# 88770  1679887              NaN                     NaN             NaN
#
#       nuDeputadoId ideDocumento  \
# 88770         2233      7020514
#
#                                             urlDocumento
# 88770  https://www.camara.leg.br/cota-parlamentar/doc...

# %% [markdown]
# #### Quais parlamentares gastaram mais de R$ 100.000,00?
#
# Independente do valor desejado, o filtro do pandas permite a gente responder essa pergunta.

# %%
df_reembolso[df_reembolso.vlrLiquido > 100000]
# Out:
#                         txNomeParlamentar           cpf ideCadastro  \
# 88770                       Weliton Prado  8.471985e+10      160518
# 109874  Professora Dorinha Seabra Rezende  4.319693e+10      160639
# 280953                     Raimundo Costa  1.767254e+10      204567
#
#        nuCarteiraParlamentar nuLegislatura sgUF sgPartido codLegislatura  \
# 88770                    270          2019   MG      PROS             56
# 109874                    67          2019   TO     UNIÃO             56
# 280953                   211          2019   BA      PODE             56
#
#        numSubCota                          txtDescricao  \
# 88770           5  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 109874          5  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 280953          5  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
#
#        numEspecificacaoSubCota txtDescricaoEspecificacao  \
# 88770                        0                       NaN
# 109874                       0                       NaN
# 280953                       0                       NaN
#
#                           txtFornecedor      txtCNPJCPF        txtNumero  \
# 88770   Athalaia Grafica e Editora Ltda  02717866000143            12497
# 109874        ALENCAR & MARTINS LTDA-ME  05649338000192  201900000003750
# 280953              ALUGUE GRAFICA LTDA  19179551000192         00002981
#
#        indTipoDocumento          datEmissao  vlrDocumento vlrGlosa  \
# 88770       nota_fiscal 2019-12-20 00:00:00      145140.0        0
# 109874      nota_fiscal 2019-12-11 00:00:00      109500.0        0
# 280953      nota_fiscal 2019-11-26 23:00:00      110000.0        0
#
#         vlrLiquido numMes numAno numParcela txtPassageiro txtTrecho  numLote  \
# 88770     145140.0     12   2019          0           NaN       NaN  1679887
# 109874    109500.0     12   2019          0           NaN       NaN  1661126
# 280953    110000.0     11   2019          0           NaN       NaN  1656271
#
#        numRessarcimento datPagamentoRestituicao  vlrRestituicao nuDeputadoId  \
# 88770               NaN                     NaN             NaN         2233
# 109874              NaN                     NaN             NaN         2300
# 280953              NaN                     NaN             NaN         3426
#
#        ideDocumento                                       urlDocumento
# 88770       7020514  https://www.camara.leg.br/cota-parlamentar/doc...
# 109874      6981838  https://www.camara.leg.br/cota-parlamentar/doc...
# 280953      6971267  https://www.camara.leg.br/cota-parlamentar/doc...

# %% [markdown]
# #### Qual a média de gastos dos parlamentares?
#
# A função `mean` pode nós ajudar com isso.

# %%
df_reembolso["vlrLiquido"].mean()
# Out:
# 730.2394855814241

# %% [markdown]
# ### Explorando mais o campo `vlrLiquido`

# %% [markdown]
# #### Soma total:

# %%
df_reembolso["vlrLiquido"].sum()
# Out:
# 211370009.81999996

# %% [markdown]
# #### Utilizando gráficos para explorar os dados

# %%
import matplotlib.pyplot as plt

# %%
plt.title("valor liquido")

plt.scatter(x=df_reembolso.index, y=df_reembolso["vlrLiquido"], s=5)
plt.hlines(y=df_reembolso["vlrLiquido"].mean(), xmin=0, xmax=df_reembolso["vlrLiquido"].count(), color="red");

# %% [markdown]
# #### Descrição dos dados

# %%
df_reembolso["vlrLiquido"].describe()
# Out:
# count    289453.000000
# mean        730.239486
# std        2083.626830
# min       -6605.570000
# 25%          50.000000
# 50%         191.840000
# 75%         715.750000
# max      145140.000000
# Name: vlrLiquido, dtype: float64

# %% [markdown]
# Aqui nós podemos ver que temos valores negativos. Esse valores são referentes a bilhetes de compensação, bilhete de compensação é o bilhete aéreo não voado, que foi reembolsado à Câmara dos Deputados. Portanto, o valor relativo aos bilhetes compensados (não voados) são reembolsados/devolvidos à Casa, deduzindo-se as taxas de cancelamento e de no-show, de acordo com as regras tarifárias da companhia aérea respectiva.
#
# Esse crédito pode voltar para a conta corrente do parlamentar mantida na companhia aérea para ser utilizado com nova emissão de passagem aérea ou poderá voltar para a CEAP do respectivo parlamentar, ficando disponível para utilização com as demais despesas.
#
# Para entender mais, vejam a thread: https://github.com/okfn-brasil/serenata-de-amor/issues/29

# %% [markdown]
# #### Explorando mais o caso dos valores negativos

# %% [markdown]
# Para entender melhor sobre esses valores, vamos recuperar todos os valores negativos.

# %%
negative_documents = df_reembolso[df_reembolso["vlrLiquido"] < 0]
len(negative_documents)
# Out:
# 10739

# %% [markdown]
# Em teoria, para cada documento negativo, vamos ter outro documento positivo relacionado.

# %%
positive_documents = df_reembolso[
    (df_reembolso["ideDocumento"].isin(negative_documents["ideDocumento"]))
    & (df_reembolso["vlrLiquido"] > 0)
]

len(positive_documents)
# Out:
# 601

# %%
positive_documents.iloc[0].to_frame()
# Out:
#                                               1758
# txNomeParlamentar                    Fausto Pinato
# cpf                                  28022995819.0
# ideCadastro                                  66828
# nuCarteiraParlamentar                          355
# nuLegislatura                                 2019
# sgUF                                            SP
# sgPartido                                       PP
# codLegislatura                                  56
# numSubCota                                     998
# txtDescricao               PASSAGEM AÉREA - SIGEPA
# numEspecificacaoSubCota                          0
# txtDescricaoEspecificacao                      NaN
# txtFornecedor                                  GOL
# txtCNPJCPF                                     NaN
# txtNumero                                   GLLN8G
# indTipoDocumento                       nota_fiscal
# datEmissao                     2019-11-20 12:00:00
# vlrDocumento                                1386.5
# vlrGlosa                                         0
# vlrLiquido                                  1386.5
# numMes                                          11
# numAno                                        2019
# numParcela                                       0
# txtPassageiro                    Fausto Ruy Pinato
# txtTrecho                                  BSB/CGH
# numLote                                          0
# numRessarcimento                                 0
# datPagamentoRestituicao                        NaN
# vlrRestituicao                                 NaN
# nuDeputadoId                                  2917
# ideDocumento                                  2203
# urlDocumento                                   NaN

# %% [markdown]
# Pegando o id do documento desse gasto positivo, podemos encontrar o documento com gasto negativo relacionado.

# %%
negative_documents[negative_documents["ideDocumento"] == positive_documents.iloc[0].ideDocumento]
# Out:
#      txNomeParlamentar           cpf ideCadastro nuCarteiraParlamentar  \
# 1759     Fausto Pinato  2.802300e+10       66828                   355
#
#      nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 1759          2019   SP        PP             56        998
#
#                  txtDescricao numEspecificacaoSubCota  \
# 1759  PASSAGEM AÉREA - SIGEPA                       0
#
#      txtDescricaoEspecificacao txtFornecedor txtCNPJCPF txtNumero  \
# 1759                       NaN           GOL        NaN    GLLN8G
#
#      indTipoDocumento          datEmissao  vlrDocumento vlrGlosa  vlrLiquido  \
# 1759      nota_fiscal 2019-12-20 12:00:00      -1318.71        0    -1318.71
#
#      numMes numAno numParcela      txtPassageiro txtTrecho numLote  \
# 1759     12   2019          0  Fausto Ruy Pinato   BSB/BSB       0
#
#      numRessarcimento datPagamentoRestituicao  vlrRestituicao nuDeputadoId  \
# 1759                0                     NaN             NaN         2917
#
#      ideDocumento urlDocumento
# 1759         2203          NaN

# %%
len(positive_documents), len(negative_documents)
# Out:
# (601, 10739)

# %%
sample = negative_documents[negative_documents.duplicated(subset="ideDocumento")].iloc[
    1
]  # , keep = {‘last’, ‘first’, ‘false’)

sample
# Out:
# txNomeParlamentar                                Bacelar
# cpf                                        10626409500.0
# ideCadastro                                        69871
# nuCarteiraParlamentar                                184
# nuLegislatura                                       2019
# sgUF                                                  BA
# sgPartido                                             PV
# codLegislatura                                        56
# numSubCota                                           998
# txtDescricao                     PASSAGEM AÉREA - SIGEPA
# numEspecificacaoSubCota                                0
# txtDescricaoEspecificacao                            NaN
# txtFornecedor                                        GOL
# txtCNPJCPF                                           NaN
# txtNumero                                         RMQ2VW
# indTipoDocumento                             nota_fiscal
# datEmissao                           2019-11-28 12:00:00
# vlrDocumento                                    -1330.14
# vlrGlosa                                               0
# vlrLiquido                                      -1330.14
# numMes                                                11
# numAno                                              2019
# numParcela                                             0
# txtPassageiro                JOAO CARLOS BACELAR BATISTA
# txtTrecho                                        BSB/BSB
# numLote                                                0
# numRessarcimento                                       0
# datPagamentoRestituicao                              NaN
# vlrRestituicao                                       NaN
# nuDeputadoId                                        2985
# ideDocumento                                        1205
# urlDocumento                                         NaN
# Name: 3136, dtype: object

# %%
df_reembolso[df_reembolso["ideDocumento"] == sample["ideDocumento"]]
# Out:
#      txNomeParlamentar           cpf ideCadastro nuCarteiraParlamentar  \
# 3134           Bacelar  1.062641e+10       69871                   184
# 3135           Bacelar  1.062641e+10       69871                   184
# 3136           Bacelar  1.062641e+10       69871                   184
#
#      nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 3134          2019   BA        PV             56        998
# 3135          2019   BA        PV             56        998
# 3136          2019   BA        PV             56        998
#
#                  txtDescricao numEspecificacaoSubCota  \
# 3134  PASSAGEM AÉREA - SIGEPA                       0
# 3135  PASSAGEM AÉREA - SIGEPA                       0
# 3136  PASSAGEM AÉREA - SIGEPA                       0
#
#      txtDescricaoEspecificacao txtFornecedor txtCNPJCPF txtNumero  \
# 3134                       NaN           GOL        NaN    RMQ2VW
# 3135                       NaN           GOL        NaN    RMQ2VW
# 3136                       NaN           GOL        NaN    RMQ2VW
#
#      indTipoDocumento          datEmissao  vlrDocumento vlrGlosa  vlrLiquido  \
# 3134      nota_fiscal 2019-09-26 12:00:00       1423.46        0     1423.46
# 3135      nota_fiscal 2019-10-01 12:00:00        -25.00        0      -25.00
# 3136      nota_fiscal 2019-11-28 12:00:00      -1330.14        0    -1330.14
#
#      numMes numAno numParcela                txtPassageiro txtTrecho numLote  \
# 3134      9   2019          0  JOAO CARLOS BACELAR BATISTA   SSA/BSB       0
# 3135     10   2019          0  JOAO CARLOS BACELAR BATISTA   SSA/BSB       0
# 3136     11   2019          0  JOAO CARLOS BACELAR BATISTA   BSB/BSB       0
#
#      numRessarcimento datPagamentoRestituicao  vlrRestituicao nuDeputadoId  \
# 3134                0                     NaN             NaN         2985
# 3135                0                     NaN             NaN         2985
# 3136                0                     NaN             NaN         2985
#
#      ideDocumento urlDocumento
# 3134         1205          NaN
# 3135         1205          NaN
# 3136         1205          NaN

# %% [markdown]
# Usando o `std` podemos entender o quanto nosso dado se desvia do 'esperado'.

# %%
df_reembolso["vlrLiquido"].std()
# Out:
# 2083.6268302833555

# %% [markdown]
# ### Trabalhando com dados agrupados

# %% [markdown]
# Antes de tudo precisaremos converter o campo `datEmissao` para o formato `datetime` (como já fizemos anteriormente)

# %%
df_reembolso["datEmissao"] = pd.to_datetime(df_reembolso.datEmissao, format="%Y-%m-%dT%H:%M:%S")

# %% [markdown]
# Algumas coisas que podemos é agrupar os registros por datas, para isso iremos utilizar o `groupby` do pandas.
#
# Após isso, poderemos realizar diversos cálculos, como por exemplo, **somar todos os registros presentes em uma data especifica**.

# %%
df_reembolso.groupby("datEmissao")["vlrLiquido"].sum().to_frame()
# Out:
#             vlrLiquido
# datEmissao
# 2018-06-13     3420.40
# 2018-11-06     1079.00
# 2018-11-12     1347.18
# 2018-11-20     3923.15
# 2018-11-22        2.30
# ...                ...
# 2020-03-12     3200.00
# 2020-03-17     3908.56
# 2020-03-19    30000.00
# 2020-03-23    37750.00
# 2020-03-30     8500.00
#
# [14169 rows x 1 columns]

# %% [markdown]
# O que mais podemos fazer com esse dados agrupados, é encontrar a **média** da soma diária de documentos fiscais:

# %%
df_reembolso.groupby("datEmissao")["vlrLiquido"].sum().mean()
# Out:
# 14893.661144752628

# %% [markdown]
# Outros agrupamentos podem ser realizados, como o a seguir:

# %%
df_reembolso.groupby("txtDescricao")["vlrLiquido"].sum().to_frame().sort_values(by='vlrLiquido', ascending=False)
# Out:
#                                                      vlrLiquido
# txtDescricao
# PASSAGEM AÉREA - RPA                                54963573.34
# DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                49187128.01
# LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES       26508130.89
# MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE P...  23208609.49
# CONSULTORIAS, PESQUISAS E TRABALHOS TÉCNICOS.       20457463.41
# COMBUSTÍVEIS E LUBRIFICANTES.                       16519513.53
# TELEFONIA                                            4882802.45
# PASSAGEM AÉREA - REEMBOLSO                           3725716.84
# PASSAGEM AÉREA - SIGEPA                              2841992.16
# SERVIÇOS POSTAIS                                     1922305.37
# HOSPEDAGEM ,EXCETO DO PARLAMENTAR NO DISTRITO F...   1765518.07
# LOCAÇÃO OU FRETAMENTO DE AERONAVES                   1465615.00
# FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR           1280375.53
# SERVIÇO DE SEGURANÇA PRESTADO POR EMPRESA ESPEC...   1086086.94
# SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO             924935.46
# ASSINATURA DE PUBLICAÇÕES                             275892.32
# PASSAGENS TERRESTRES, MARÍTIMAS OU FLUVIAIS           136452.31
# PARTICIPAÇÃO EM CURSO, PALESTRA OU EVENTO SIMILAR     112048.70
# LOCAÇÃO OU FRETAMENTO DE EMBARCAÇÕES                  105850.00

# %% [markdown]
# Nesse agrupamento, encontramos qual o valor líquido total dos documentos, agrupados por descrição.

# %% [markdown]
# Perguntas mais complexas, como "Quais os parlamentares que mais gastaram, a qual partido e a qual estado eles pertencem?", também pode ser respondido agrupando os dados.

# %%
import numpy as np

df_reembolso.groupby(["sgPartido", "sgUF", "txNomeParlamentar"], as_index=False).aggregate(
    {"vlrLiquido": np.sum}
).sort_values(by="vlrLiquido", ascending=False).head()
# Out:
#     sgPartido sgUF txNomeParlamentar  vlrLiquido
# 370        PP   RR   Hiran Gonçalves   542487.76
# 61        MDB   AC     Jéssica Sales   537322.05
# 188       PDT   RS      Afonso Motta   537270.79
# 147     PCdoB   AC  Perpétua Almeida   536138.75
# 60        MDB   AC     Flaviano Melo   520071.45

# %% [markdown]
# Por fim, último exemplo que podemos ver hoje é o caso de quais são os fornecedores mais presentes nas solicitações de reembolso.

# %%
df_reembolso.groupby(["txtCNPJCPF", "txtFornecedor"], as_index=False).agg(
    {"vlrLiquido": np.nansum}
).sort_values(by="vlrLiquido", ascending=False)[0:20]
# Out:
#            txtCNPJCPF                                      txtFornecedor  \
# 1912   02012862000160                                    Cia Aérea - TAM
# 7240   07575651000159                                    Cia Aérea - GOL
# 8971   09296295000160                                   Cia Aérea - AZUL
# 6952   07319323000191                             PANTANAL VEÍCULOS LTDA
# 1917   02012862000160                             TAM LINHAS AEREAS S/A.
# 2612   02575829000148                                Cia Aérea - AVIANCA
# 16156  23721017000133     T2 COMUNICACAO, VIDEO E PRODUCOES EIRELI - EPP
# 3      00000000000001                                  CELULAR FUNCIONAL
# 2528   02558157000162                        TELEFÔNICA BRASIL S.A. VIVO
# 2646   02610235000120                DMD Gestão Administrativa LTDA - ME
# 17333  26735227000179          GOLD CAR BRASILIA LOCADORA DE VEICULOS ME
# 5576   05443449000148  VERTICE - SOCIEDADE CIVIL DE PROFISSIONAIS ASS...
# 7242   07575651000159                             GOL LINHAS AEREAS S.A.
# 18202  28800786000140                  GP COBERTURA JORNALISTICA LTDA ME
# 8029   08345631000154               LIBRE COMUNICAÇÃO E MARKETING EIRELI
# 12728  15702383000117                          RAMA AGENCIA DIGITAL LTDA
# 10919  12132854000100       WMS COMERCIO DE ARTIGOS DE PAPELARIA LTDA-ME
# 740    00512777000135                              Cia Aérea - PASSAREDO
# 8488   08865615000192      WORKING ASSOCIACAO DE INTEGRACAO PROFISSIONAL
# 10635  11630318000172                            LINDERLANDIO BARBOSA ME
#
#         vlrLiquido
# 1912   24922866.52
# 7240   22007041.30
# 8971    6440767.66
# 6952    2181274.52
# 1917    1172126.78
# 2612    1137800.63
# 16156   1097334.00
# 3        872853.43
# 2528     860813.15
# 2646     805000.00
# 17333    766486.73
# 5576     709867.00
# 7242     618314.80
# 18202    513500.00
# 8029     496000.00
# 12728    462450.00
# 10919    455316.20
# 740      455097.23
# 8488     445200.00
# 10635    405850.00

# %% [markdown]
# ## Aula 07: Dados da Receita Federal

# %% [markdown]
# Referencias:
#
# - https://www.gov.br/receitafederal/pt-br/assuntos/orientacao-tributaria/cadastros/consultas/dados-publicos-cnpj
# - http://200.152.38.155/CNPJ/LAYOUT_DADOS_ABERTOS_CNPJ.pdf
#
#
# situation (Situação cadastral)
#
#     1 – NULA: o CNPJ torna-se inválido, seja por inconformidade de dados, fraudes ou outros motivos.
#     2 – ATIVA: significa que a empresa está em dia com todas as suas pendências, não há nenhuma irregularidade e os pagamentos estão em dia;
#     3 – SUSPENSA: a empresa tem pendências com a Receita Federal, não cumpriu com suas obrigações ou pagamentos ou está sendo investigada por possível fraude;
#     4 – INAPTA: a empresa está a dois anos ou mais com suspensão e não apresentou os devidos dados contábeis;
#     8 – BAIXADA: a empresa foi extinta, seja por solicitação dos sócios ou por ação da Receita;
#
#
# situation_date (Data da situação cadastral): DATA DO EVENTO DA SITUACAO CADASTRAL

# %%
import requests

url = "https://serenata-de-amor-data.nyc3.digitaloceanspaces.com/2019-11-19-companies.csv.xz"

# fazendo o download do conteúdo do arquivo
r = requests.get(url)

# abrindo um arquivo no seu computador
file = open("2019-11-19-companies.csv.xz", "wb")

# escrever o conteúdo
file.write(r.content)
file.close()

# %%
import pandas as pd

DTYPE = {
    "cnpj": str,
}

df_empresas = pd.read_csv(
    "2019-11-19-companies.csv.xz",
    compression="xz",
    dtype=DTYPE,
)
df_empresas.head(1)
# Out:
#              cnpj                                           partners  \
# 0  08771105000156  [{"id": 2, "name": "MARLY MORAIS DA GAMA", "cn...
#
#    secondary_activities  latitude  longitude  opening  main_activity  \
# 0                   NaN       NaN        NaN      NaN            NaN
#
#   neighborhood  share_capital    zip_code  main_activity_code  city_code  \
# 0      REALEZA        10000.0  36900000.0             5611201       4787
#
#    judicial_nature_code additional_address_details removed_from_simples_since  \
# 0                  2062                      KM 51                 2016-12-31
#
#     opened_in opted_for_comples_in situation_date special_situation_date  \
# 0  2007-04-12           2016-01-01     2007-04-12                    NaN
#
#   fax_area_code phone1_area_code phone2_area_code address_type  \
# 0  33  33331212     33  33331222     33  33312882      AVENIDA
#
#    responsible_federative_entity  hq_or_subsidiary_code        address  \
# 0                            NaN                      1  VITORIA MINAS
#
#    situation_reason      city  legal_entity  city_abroad_name  \
# 0                 0  MANHUACU           NaN               NaN
#
#                                   trade_name number  mei  simples  size  \
# 0  LANCHONETE E RESTAURANTE PEQUENO PRINCIPE    S/N    0        0     1
#
#    administrative_person_category                                name  \
# 0                              49  WERNER COMERCIAL DE ALIMENTOS LTDA
#
#    situation special_situation  phone  type state  last_updated
# 0          2               NaN    NaN   NaN    MG           NaN

# %%
df_empresas["situation_date"] = pd.to_datetime(df_empresas["situation_date"], format="%Y-%m-%d")

# %%
df_empresas["cnpj"] = df_empresas["cnpj"].str.replace(r"\D", "", regex=True)

# %%
df_empresas.head(5)
# Out:
#              cnpj                                           partners  \
# 0  08771105000156  [{"id": 2, "name": "MARLY MORAIS DA GAMA", "cn...
# 1  42149328000114  [{"id": 2, "name": "SINESIO SEBASTIAO LELIS", ...
# 2  01155685000108  [{"id": 2, "name": "CASSIUS PELUSO FRADE", "cn...
# 3  09161591000153  [{"id": 2, "name": "JOSE DO LIVRAMENTO PEREIRA...
# 4  03048166000176  [{"id": 2, "name": "CARLOS FINATTO BELLE", "cn...
#
#    secondary_activities  latitude  longitude  opening  main_activity  \
# 0                   NaN       NaN        NaN      NaN            NaN
# 1                   NaN       NaN        NaN      NaN            NaN
# 2                   NaN       NaN        NaN      NaN            NaN
# 3                   NaN       NaN        NaN      NaN            NaN
# 4                   NaN       NaN        NaN      NaN            NaN
#
#   neighborhood  share_capital    zip_code  main_activity_code  city_code  \
# 0      REALEZA        10000.0  36900000.0             5611201       4787
# 1      PARAISO       250000.0  46430000.0             4731800       3533
# 2     CAICARAS        50000.0  31230070.0             4751201       4123
# 3       CENTRO       130000.0  65378000.0             4731800        260
# 4   BELA VISTA        40000.0   1319010.0             5823900       7107
#
#    judicial_nature_code additional_address_details removed_from_simples_since  \
# 0                  2062                      KM 51                 2016-12-31
# 1                  2062                        NaN                        NaN
# 2                  2062                        NaN                        NaN
# 3                  2062                    CASA  A                        NaN
# 4                  2062                      E 201                        NaN
#
#     opened_in opted_for_comples_in situation_date special_situation_date  \
# 0  2007-04-12           2016-01-01     2007-04-12                    NaN
# 1  1992-10-14                  NaN     2005-11-03                    NaN
# 2  1996-04-16           2012-01-01     2005-11-03                    NaN
# 3  2007-10-30                  NaN     2007-10-30                    NaN
# 4  1999-03-15                  NaN     2005-08-27                    NaN
#
#   fax_area_code phone1_area_code phone2_area_code address_type  \
# 0  33  33331212     33  33331222     33  33312882      AVENIDA
# 1  77  34516106     77  34516106     77  34513458      AVENIDA
# 2  31  32748180     31  33141850              NaN          RUA
# 3           NaN     98  11111111              NaN          RUA
# 4  11  33370933     11  33370933     11  33370933          RUA
#
#    responsible_federative_entity  hq_or_subsidiary_code               address  \
# 0                            NaN                      1         VITORIA MINAS
# 1                            NaN                      1  PREF JOSE N TEIXEIRA
# 2                            NaN                      1               CATUMBI
# 3                            NaN                      1       COSTA RODRIGUES
# 4                            NaN                      1              ABOLICAO
#
#    situation_reason            city  legal_entity  city_abroad_name  \
# 0                 0        MANHUACU           NaN               NaN
# 1                 0        GUANAMBI           NaN               NaN
# 2                 0  BELO HORIZONTE           NaN               NaN
# 3                 0      TUFILANDIA           NaN               NaN
# 4                 0       SAO PAULO           NaN               NaN
#
#                                   trade_name number  mei  simples  size  \
# 0  LANCHONETE E RESTAURANTE PEQUENO PRINCIPE    S/N    0        0     1
# 1                             POSTO GUANAMBI    850    0        0     5
# 2                                        NaN    546    0        1     1
# 3                             POSTO AMSTERDA    101    0        0     3
# 4       EDITORA E LIVRARIA EXPRESSAO POPULAR    197    0        0     5
#
#    administrative_person_category  \
# 0                              49
# 1                              49
# 2                              49
# 3                              49
# 4                              49
#
#                                               name  situation  \
# 0               WERNER COMERCIAL DE ALIMENTOS LTDA          2
# 1                              POSTO GUANAMBI LTDA          2
# 2           DOCUMENTO POINT SOLUCOES DIGITAIS LTDA          2
# 3  AMSTERDA COMERCIO DE DERIVADOS DE PETROLEO LTDA          2
# 4                   EDITORA EXPRESSAO POPULAR LTDA          2
#
#   special_situation  phone  type state  last_updated
# 0               NaN    NaN   NaN    MG           NaN
# 1               NaN    NaN   NaN    BA           NaN
# 2               NaN    NaN   NaN    MG           NaN
# 3               NaN    NaN   NaN    MA           NaN
# 4               NaN    NaN   NaN    SP           NaN

# %%
df_final = df_reembolso.merge(df_empresas, how="left", left_on="txtCNPJCPF", right_on="cnpj")

# %%
df_final.sample(5)
# Out:
#            txNomeParlamentar           cpf ideCadastro nuCarteiraParlamentar  \
# 467334  Capitão Alberto Neto  6.639755e+10      204572                    36
# 389689        Vinicius Farah  9.180474e+10      204478                   324
# 235371         Tadeu Alencar  3.528442e+10      178922                   161
# 175318           Pedro Uczai  4.772186e+10      160604                   481
# 24097       Darcísio Perondi  8.262748e+09       73891                   529
#
#        nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 467334          2019   AM        PL             56          1
# 389689          2019   RJ     UNIÃO             56        999
# 235371          2019   PE       PSB             56          3
# 175318          2019   SC        PT             56         13
# 24097           2019   RS       MDB             56          3
#
#                                              txtDescricao  \
# 467334  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 389689                               PASSAGEM AÉREA - RPA
# 235371                      COMBUSTÍVEIS E LUBRIFICANTES.
# 175318         FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 24097                       COMBUSTÍVEIS E LUBRIFICANTES.
#
#        numEspecificacaoSubCota txtDescricaoEspecificacao  \
# 467334                       0                       NaN
# 389689                       0                       NaN
# 235371                       1      Veículos Automotores
# 175318                       0                       NaN
# 24097                        1      Veículos Automotores
#
#                                  txtFornecedor      txtCNPJCPF  \
# 467334                             NET - CLARO  40432544024321
# 389689                         Cia Aérea - GOL  07575651000159
# 235371      EDUARDO E INACIO COMBUSTIVEIS LTDA  07027843000120
# 175318                     JG Restaurante Ltda  24606549000192
# 24097   CASCOL COMBUSTIVEIS PARA VEICULOS LTDA  00306597001926
#
#               txtNumero indTipoDocumento          datEmissao  vlrDocumento  \
# 467334     121221646128      nota_fiscal 2019-12-25 00:00:00        168.97
# 389689  Bilhete: YQKZHK      nota_fiscal 2019-08-22 00:00:00       1103.57
# 235371            45470      nota_fiscal 2019-10-20 23:00:00         80.00
# 175318           143544             None 2019-03-20 00:00:00         30.00
# 24097            525762             None 2019-10-31 00:00:00        117.71
#
#        vlrGlosa  vlrLiquido numMes numAno numParcela   txtPassageiro  \
# 467334        0      168.97     12   2019          0             NaN
# 389689        0     1103.57      8   2019          0  Vinicius Farah
# 235371        0       80.00     10   2019          0             NaN
# 175318        0       30.00      3   2019          0             NaN
# 24097         0      117.71     10   2019          0             NaN
#
#        txtTrecho  numLote numRessarcimento datPagamentoRestituicao  \
# 467334       NaN  1675383              NaN                     NaN
# 389689   BSB/GIG        0                0                     NaN
# 235371       NaN  1649757              NaN                     NaN
# 175318       NaN  1578631              NaN                     NaN
# 24097        NaN  1648365              NaN                     NaN
#
#         vlrRestituicao nuDeputadoId ideDocumento  \
# 467334             NaN         3333      7012414
# 389689             NaN         3356      1698497
# 235371             NaN         2945      6955441
# 175318             NaN         2243      6791819
# 24097              NaN          999      6952123
#
#                                              urlDocumento            cnpj  \
# 467334  https://www.camara.leg.br/cota-parlamentar/doc...  40432544024321
# 389689                                                NaN  07575651000159
# 235371  https://www.camara.leg.br/cota-parlamentar/doc...  07027843000120
# 175318  https://www.camara.leg.br/cota-parlamentar/not...  24606549000192
# 24097   https://www.camara.leg.br/cota-parlamentar/not...  00306597001926
#
#                                                  partners  \
# 467334  [{"id": 2, "name": "RODRIGO MARQUES DE OLIVEIR...
# 389689  [{"id": 2, "name": "PAULO SERGIO KAKINOFF", "c...
# 235371  [{"id": 2, "name": "JOSE INACIO DOS SANTOS", "...
# 175318  [{"id": 2, "name": "JULIA ANTONIA MENNA BARRET...
# 24097   [{"id": 2, "name": "ELSON CASCAO", "cnpj_cpf":...
#
#         secondary_activities   latitude  longitude  opening  main_activity  \
# 467334                   NaN        NaN        NaN      NaN            NaN
# 389689                   NaN -22.911154 -43.167131      NaN            NaN
# 235371                   NaN        NaN        NaN      NaN            NaN
# 175318                   NaN        NaN        NaN      NaN            NaN
# 24097                    NaN        NaN        NaN      NaN            NaN
#
#                     neighborhood  share_capital    zip_code  \
# 467334  COLONIA OLIVEIRA MACHADO   0.000000e+00  69070625.0
# 389689                    CENTRO   4.554280e+09  20021340.0
# 235371                ZONA RURAL   4.240000e+05  55630000.0
# 175318                 ASA NORTE   1.000000e+05  70735520.0
# 24097                    ASA SUL   0.000000e+00  70336000.0
#
#         main_activity_code  city_code  judicial_nature_code  \
# 467334           6120501.0      255.0                2054.0
# 389689           5111100.0     6001.0                2054.0
# 235371           4731800.0     2525.0                2062.0
# 175318           5611201.0     9701.0                2305.0
# 24097            4731800.0     9701.0                2062.0
#
#                                additional_address_details  \
# 467334                                                NaN
# 389689  TERREOAEREA PUBLICA             ENT EIXOS 46-4...
# 235371                                                NaN
# 175318                                              SUBSL
# 24097                                                 NaN
#
#        removed_from_simples_since   opened_in opted_for_comples_in  \
# 467334                        NaN  2008-01-15                  NaN
# 389689                        NaN  2005-08-31                  NaN
# 235371                        NaN  2004-10-13                  NaN
# 175318                        NaN  2016-04-15           2019-01-01
# 24097                         NaN  2012-01-03                  NaN
#
#        situation_date special_situation_date fax_area_code phone1_area_code  \
# 467334     2008-01-15                    NaN  92  35840200     11  21112161
# 389689     2005-08-31                    NaN  11  28412702     11  28412702
# 235371     2004-10-13                    NaN           NaN              NaN
# 175318     2016-04-15                    NaN           NaN     61  30332955
# 24097      2012-01-03                    NaN           NaN     61  32178536
#
#        phone2_area_code address_type  responsible_federative_entity  \
# 467334              NaN      AVENIDA                            NaN
# 389689     11  77523231        PRACA                            NaN
# 235371              NaN      RODOVIA                            NaN
# 175318     61  30342955       QUADRA                            NaN
# 24097      61  32178526        SETOR                            NaN
#
#         hq_or_subsidiary_code                  address  situation_reason  \
# 467334                    2.0       PRESIDENTE KENNEDY               0.0
# 389689                    1.0    SENADOR SALGADO FILHO               0.0
# 235371                    1.0         BR 232 - KM 55,9               0.0
# 175318                    1.0     CLN 303 BLOCO B LOJA               0.0
# 24097                     2.0  SHCS SQ 303 BLOCO A PLL               0.0
#
#                   city  legal_entity  city_abroad_name  \
# 467334          MANAUS           NaN               NaN
# 389689  RIO DE JANEIRO           NaN               NaN
# 235371          POMBOS           NaN               NaN
# 175318        BRASILIA           NaN               NaN
# 24097         BRASILIA           NaN               NaN
#
#                                     trade_name number  mei  simples  size  \
# 467334                                   CLARO   1020  0.0      0.0   5.0
# 389689                                     NaN    S/N  0.0      0.0   5.0
# 235371                  AUTO POSTO SAO JOSE II    S/N  0.0      0.0   5.0
# 175318                       BIOON RESTAURANTE     06  0.0      1.0   1.0
# 24097   CASCOL COMBUSTIVEIS PARA VEICULOS LTDA    S/N  0.0      0.0   5.0
#
#         administrative_person_category  \
# 467334                            16.0
# 389689                            16.0
# 235371                            49.0
# 175318                            65.0
# 24097                             49.0
#
#                                           name  situation special_situation  \
# 467334                              CLARO S.A.        2.0               NaN
# 389689                  GOL LINHAS AEREAS S.A.        2.0               NaN
# 235371      EDUARDO & INACIO COMBUSTIVEIS LTDA        2.0               NaN
# 175318                BIOON RESTAURANTE EIRELI        2.0               NaN
# 24097   CASCOL COMBUSTIVEIS PARA VEICULOS LTDA        2.0               NaN
#
#         phone  type state  last_updated
# 467334    NaN   NaN    AM           NaN
# 389689    NaN   NaN    RJ           NaN
# 235371    NaN   NaN    PE           NaN
# 175318    NaN   NaN    DF           NaN
# 24097     NaN   NaN    DF           NaN

# %% [markdown]
# ### Exportando o resultado

# %%
df_reembolso.to_csv("reembolso-2019-completo.csv")
